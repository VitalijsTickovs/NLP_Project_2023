# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import re    # for regular expressions
from string import punctuation
from nltk.stem import SnowballStemmer    #if you are brave enough to do stemming
from nltk.corpus import stopwords      #if you want to remove stopwords
from nltk.tokenize import word_tokenize
import string
from collections import Counter

# %% [markdown]
# ### Data visualization

# %%
# Import products

products = pd.read_csv('products_train.csv')
products.head()
# Out:
#            id locale                                              title  \
# 0  B005ZSSN10     DE  RED DRAGON Amberjack 3 - Steel Tip 22 Gramm Wo...
# 1  B08PRYN6LD     DE  Simply Keto Lower Carb* Schokodrops ohne Zucke...
# 2  B09MBZJ48V     DE  Sennheiser 508377 PC 5.2 Chat, Stilvolles Mult...
# 3  B08ZN6F26S     DE  AmyBenton Auto ab 1 2 3 ahre - Baby Aufziehbar...
# 4  B094DGRV7D     DE      PLAYMOBIL - 70522 - Cavaliere mit grauem Pony
#
#    price         brand              color              size    model  \
# 0  30.95    RED DRAGON                NaN               NaN  RDD0089
# 1  17.90   Simply Keto                NaN  750 g (1er Pack)      NaN
# 2  68.89    Sennheiser       Multi-Colour          One size   508377
# 3  18.99  Amy & Benton         Animal Car               NaN    2008B
# 4   7.17     PLAYMOBIL  Nicht Zutreffend.           OneSize    70522
#
#              material author  \
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2          Kunstleder    NaN
# 3  aufziehauto 1 jahr    NaN
# 4        Polypropylen    NaN
#
#                                                 desc
# 0  Amberjacks Steel Dartpfeile sind verfügbar in ...
# 1  🌱 NATÜRLICHE SÜSSE DURCH ERYTHRIT - Wir stelle...
# 2  3.5 MM BUCHSE - Kann problemlos an Geräte mit ...
# 3  【Auto aufziehbar】: Drücken Sie einfach leicht ...
# 4                                    Inhalt: 1 Stück

# %%
# Import sessions

sessions = pd.read_csv('sessions_train.csv')
sessions.head()
# Out:
#                                           prev_items   next_item locale
# 0                        ['B09W9FND7K' 'B09JSPLN1M']  B09M7GY217     DE
# 1  ['B076THCGSG' 'B007MO8IME' 'B08MF65MLV' 'B001B...  B001B4THSA     DE
# 2  ['B0B1LGXWDS' 'B00AZYORS2' 'B0B1LGXWDS' 'B00AZ...  B0767DTG2Q     DE
# 3  ['B09XMTWDVT' 'B0B4MZZ8MB' 'B0B7HZ2GWX' 'B09XM...  B0B4R9NN4B     DE
# 4           ['B09Y5CSL3T' 'B09Y5DPTXN' 'B09FKD61R8']  B0BGVBKWGZ     DE

# %%
# temp_session = sessions.copy()

# %%
sessions_eng = sessions[sessions['locale']=='UK']

# %%
def clean_items(text):

    text = text[1:-1]
    text = re.findall(r"'([^']*)'", text)

    return text

# %%
sessions_eng['prev_items'] = sessions_eng['prev_items'].apply(clean_items)
# Out:
# C:\Users\Dacia Logan\AppData\Local\Temp\ipykernel_12964\932254714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sessions_eng['prev_items'] = sessions_eng['prev_items'].apply(clean_items)

# %%
interacted_items = list(sessions_eng['prev_items'])
interacted_items
# Out:
# [['B0BFDL54Y7', 'B0BFDR9X13', 'B07J4WF8VH', 'B07Y21LDJX'],
#  ['B07FM2GLNQ', 'B07GZW3P4W'],
#  ['B0021L95HU', 'B07DDL77RY', 'B07DDL77RY'],
#  ['B0B2WSZYL2', 'B000I8XZ7O'],
#  ['B00LW1APOC', 'B00LW1APOC', 'B00OI6NQUI', 'B09HLDN8W1'],
#  ['B079DXT1JM', 'B079DZRVDF', 'B079FD3MGB'],
#  ['B09X37JZ54', 'B0B9GH9597', 'B0B9GHMSXS', 'B074PQTR4W'],
#  ['B094VLF9QV', 'B07ZBKD187'],
#  ['B0954WV7VV', 'B09VN6XSDW', 'B0B2R1KL5G'],
#  ['B0845XT59N', 'B00474K8SY', 'B008BZVCVM'],
#  ['B081KHS89M', 'B08W6W1SP1', 'B00D8CXYXC'],
#  ['B0B4V1BH4L', 'B09S642Y37', 'B0BDZXD2NC', 'B0BB61MC84'],
#  ['B005C3R4WM', 'B00439VO6I', 'B00J5EVMOA', 'B006MW0G5E'],
#  ['1509800697',
#   '1509800662',
#   'B07XLTQQJN',
#   'B07XVP3R4F',
#   'B07BR8JQWC',
#   'B07BR8JQWC',
#   'B002GJFLQ6'],
#  ['B0B18M5PWY',
#   'B095SZXGG5',
#   'B095SX1S12',
#   'B0BBSVZ7SR',
#   'B072BP5SCL',
#   'B06XT1BSD9',
#   'B0B993L23X',
#   'B08DM17RDG',
#   'B08DM1BC3F',
#   'B09Q6KCGC4',
#   'B09Q73K99D',
#   'B0017IMOL2'],
#  ['B0B15M68SJ', 'B007531X5Q', 'B096KJDMKF', 'B019VXFEQ6'],
#  ['B003ZGE1G0',
#   'B09GRZNR5S',
#   'B07MJHNH1R',
#   'B09GRZNR5S',
#   'B003ZGE1G0',
#   'B07KFXGKXW'],
#  ['B07PC5WFLY',
#   'B01N9T11QZ',
#   'B07PC5WFLY',
#   'B07KQ2XK98',
#   'B072Q46W7W',
#   'B000P4IQSO',
#   'B000P4KR5E',
#   'B002UHKARY',
#   'B01GULTSSW',
#   'B00GGKMNTO'],
#  ['B08F91FYHF', 'B08F8SQFT8', 'B09QT4W8NN', 'B088PF1RTG', 'B09PQSVFQT'],
#  ['B0B6Q94GJN',
#   'B0B6Q57D3N',
#   'B0B6Q94GJN',
#   'B09GMKWYVD',
#   'B08V3QRR2G',
#   '1091252300',
#   'B07QWYXM8P',
#   'B07QV24KD7'],
#  ['B09VSZ6ZW9', 'B09JZNZ9JK', 'B09MKM7R4L'],
#  ['B07D3MXS3T', 'B073DKK4XS', 'B09RPQLSY4', 'B09RPQLSY4'],
#  ['B07WNXVZ2V',
#   'B07WNXVZ2V',
#   'B07WTXB9V7',
#   'B00UXMRR1A',
#   'B07WWZCF26',
#   'B09XHZ6K1D'],
#  ['B08NY9K9HS', 'B08NYDS3QZ'],
#  ['B09PQHMNS3', 'B092ZT1R5G', 'B0876SKD3M'],
#  ['B079Z5F358',
#   'B073FDW497',
#   'B007VXOFQY',
#   'B09V5MXCLS',
#   'B079Z1842Q',
#   'B073FDW497',
#   'B01F3B7MQA',
#   'B01DXYX9H0',
#   'B002B8IMT0',
#   'B002IJKQEQ',
#   'B07G5QMDCZ',
#   'B073FDW497',
#   'B01F3B7MQA',
#   'B01DXYX9H0',
#   'B007N4QZPA'],
#  ['B002H9WUNW',
#   'B001D34Z9U',
#   'B0B8CKSXZN',
#   'B0B8CCDHZ1',
#   'B0BB7D23TG',
#   'B09MSYCPDC',
#   'B09MT17LTV',
#   'B09MSYSKLT',
#   'B09V4D3GFG',
#   'B0B3LZ9Q34'],
#  ['B07ZMY8YDX', 'B09PFYM1CR'],
#  ['B09NSTTSDB',
#   'B000C1VSSA',
#   'B000CR1WUI',
#   'B000C1VSSA',
#   'B000CR1WUI',
#   'B07QCPP9ZN',
#   'B09W9NTFBY',
#   'B09W9NWHW9',
#   'B0BFPL7TZK',
#   'B09W9NTFBY',
#   'B09W9NWHW9',
#   'B0BFPL7TZK'],
#  ['B08DXYVZG3', 'B07L8BC875'],
#  ['B00028XNNG', 'B09R47CD4S'],
#  ['B091D9P4L6', 'B091DD9RWF', 'B091D7H53R'],
#  ['B08LLSBQP7', 'B08LLSBQP7', 'B016AB6UFG'],
#  ['B09G9HFFRR', 'B09G9643BN'],
#  ['B01D58042W', 'B01D58042W', 'B09T8DJ4RS'],
#  ['B08CMQN91C', 'B08PNZ5P1D'],
#  ['B08KFR7BYQ', 'B082KKLQQD', 'B01M68E330'],
#  ['B00KVIDJRM', 'B081QVSWMY', 'B007HKAUS8', 'B081QVSWMY', 'B00KVIDJRM'],
#  ['B099L4H28Q', 'B099L4H28Q'],
#  ['B0B8N19TRY', 'B0B87K1Y8S'],
#  ['B078J98M7C', 'B09B6SHNDW'],
#  ['B09QT6W7SX',
#   'B09QT5VZGN',
#   'B07C75D9NH',
#   'B08SC2FHDC',
#   'B094XJQZCY',
#   'B094XR74P3',
#   'B094XJQZCY',
#   'B094XR74P3'],
#  ['B095T3WH3T', 'B08KFD4ST2'],
#  ['B00JFC4OX8', 'B00RN2FL7K', 'B001DXNRXA'],
#  ['B08JTV11WX',
#   'B083TBJZHQ',
#   'B07WNRN9WQ',
#   'B09C8MLVZ5',
#   'B087M9WZL7',
#   'B0858X93K2',
#   'B0B2L5C49R',
#   'B083W1SDK1'],
#  ['B08Q7THPFJ', 'B08CS8TPGJ'],
#  ['B08VJ2VH2J', 'B08VJ2VH2J'],
#  ['B09B4CBMS5', 'B0BF62RK5N'],
#  ['B09QXCMPD6', 'B002VQWMY8'],
#  ['B095BYTP7V',
#   'B095BZZKT5',
#   'B095BYTP7V',
#   'B095BZZKT5',
#   'B09WNF34PF',
#   'B09WNDFDX1',
#   'B07SRVGZSF'],
#  ['B01JAK7UAS', 'B00R4O1H0M', 'B07MD4LB49', 'B08CRJ62T8', 'B08YK2RPBZ'],
#  ['B09YCRBHNS', 'B00A0GY0UK'],
#  ['B01ITF57A0', 'B00DPICES0'],
#  ['B01LCNXF64', 'B079BZRV73', 'B01LCNXF64', 'B079BZRV73', 'B09R23H81F'],
#  ['B017G68T7Q',
#   'B0B4D7L246',
#   'B09Y5C7DK5',
#   'B09Y59JQV5',
#   'B09Y5D1RKN',
#   'B09Y59WHMX',
#   'B017G68T7Q'],
#  ['B00V6GUG74', 'B07Z7C88XR'],
#  ['B092QJK214', 'B09DKB217S', 'B01HPR08S4'],
#  ['B08JTGQV8F',
#   'B09HXTWW8Y',
#   'B07XNL8YP1',
#   'B09CCQ8BY3',
#   'B09CCZNH2Q',
#   'B0B7P2Z5QX',
#   'B07XS87CGH',
#   'B0B3JR6BDB',
#   'B0B3JPBDNQ',
#   'B0B6VMRKQP',
#   'B0B7V6ZSS8',
#   'B0B7VKFKDZ',
#   'B0B7S32JPL',
#   'B0B99M9VVF'],
#  ['B08MJY1CY8', 'B08MJ1XB12'],
#  ['B07M93T798', 'B0B3D7RQW7', 'B0B4S9MZV5', 'B09P36C572', 'B0B1CQWPKN'],
#  ['B09WCW3T93', 'B00WAKQP70', 'B06ZZPRHNH'],
#  ['B095SWF2J6', 'B08FXNBWG8', 'B08FXNBWG8'],
#  ['B0B8D7ZSSH', 'B0B8D5MG5J', 'B0B8D2FZ71'],
#  ['B0B9FYGSL8', 'B09GZHFLGF', 'B08L6PZR51', 'B08L4FL8QZ'],
#  ['B00782C5OM', 'B001FKZAQI', 'B00AXA4PJ4'],
#  ['B002YNV3I4', 'B0043R2Q3U'],
#  ['B07QV6GZ6P', 'B09TDKVSFD'],
#  ['B09JBL2K42', 'B00MQRT2UY', 'B00H99CVZC', 'B00H99CVZC', 'B00MQRT2UY'],
#  ['B08DK6D9VV', 'B094QRPS2V', 'B08LT1149R', 'B09N37DWN3'],
#  ['B09PJYYNKZ', 'B09PJZJFB6', 'B09PJYNB83', 'B0097S2UNQ'],
#  ['B0B3J3B1VT', 'B07CS3ZZLV'],
#  ['B086H577CG', 'B08FST5KW6'],
#  ['B0B8YWCG37', 'B0B8YYMLRB', 'B0B8YWNF5L'],
#  ['B08MTDXNYM', 'B01N6IW11E', 'B01N2VYF50', 'B088P5CX9F'],
#  ['B07WR11L34', 'B07WWV3M75'],
#  ['B09QSY77Q3', 'B09MZCY1LZ', 'B0BCFTV87D'],
#  ['B0B4D1SXD1',
#   'B09PH2ZJQW',
#   'B0B4D1SXD1',
#   'B09PH2ZJQW',
#   'B0B4D1SXD1',
#   'B09PH2ZJQW',
#   'B09ZXW96WJ',
#   'B0B4D1SXD1',
#   'B09PH2ZJQW',
#   'B09ZXW96WJ'],
#  ['B0B7DN8DSC', 'B09ZTFKXGF', 'B0B119HX9Q', 'B0B5TRTPDR'],
#  ['B093HR9XK2', 'B006MG4CIM', 'B073S5BMPH', 'B073S5BMPH'],
#  ['B09HGPRW27', 'B0875NB89J'],
#  ['B06VVQ35M2', 'B01NBMYWIN', 'B01NCPFGQ3', 'B01N0U5UDH'],
#  ['B0B8DTJXBR', 'B0B8DTJXBR'],
#  ['B08BJ7ZSV3', 'B09YGNVXH2', 'B09YGFZ3SV', 'B09MZ9LJSJ'],
#  ['B09G2L9WRB', 'B09D3F9FN9', 'B09MD3TMMJ'],
#  ['B083FB8TSC', 'B09QT5SYB1'],
#  ['B077BVLRSR', 'B08C9B7GW3'],
#  ['B08QW2FYLT', 'B08QW481RJ', 'B08QW1V74W', 'B0BC8FJCG2'],
#  ['B07T721GK8',
#   'B09BW4RTJZ',
#   'B09NNK3QVL',
#   'B09NNK3QVL',
#   'B07H8MF3FC',
#   'B07B2WRNZD'],
#  ['B08QYZ6NRC', 'B08NT1TG9M', 'B07P96N5YN', 'B07P96N5YN', 'B07T8HXQTD'],
#  ['B09MHZSZZW', 'B0784B77P3', 'B07HLN84PW', 'B0912T9PVG'],
#  ['B07KRN58WG',
#   'B01AY1E6AE',
#   'B09Y5V2TBP',
#   'B0B8SB3S5B',
#   'B09Y5V2TBP',
#   'B09P44F2RK',
#   'B002CZPSQ2'],
#  ['B07ZP61N7W', 'B087X8CYX7', 'B07ZP61N7W'],
#  ['B01FNRWFO8', 'B01L3ZP2MG'],
#  ['B09XSY67LT', 'B09THYTWZS', 'B09Q34G1VG', 'B09TR4W65B', 'B09TR4W65B'],
#  ['B0B7L62QSB', 'B0798WNXBY'],
#  ['B07GXXBD26', 'B06X96CXN1'],
#  ['B09VBMV5BM', 'B0BC86FKGT', 'B09TSKD2N5'],
#  ['B07XY2KZMT', 'B08LDN4CWP'],
#  ['B09GG6RF67', 'B075H346K1'],
#  ['B0BHN2162J', 'B0BHN4V1RF', 'B0BGPVCMHP'],
#  ['B019YMITCU', 'B00I16YWJU'],
#  ['B08BKXP94B', 'B09KV3VLP9', 'B095KLTD8Y', 'B09KV3VLP9', 'B095KLTD8Y'],
#  ['B09RXZ8TZ7', 'B07147JJ8T'],
#  ['B0B4WFG2TG', 'B0B2NPNV9B', 'B07V8S7CMM'],
#  ['B003JKFEL8', 'B0BJDCPDZ6'],
#  ['B0B8M3SBJR', 'B0B93HYNQ8', 'B0B93KH8BP', 'B09GB98PXH'],
#  ['B09DGLC7X2', 'B08NZ52QZL', 'B09ZF1W6X8', 'B07DY15BXJ', 'B07T6JGT4G'],
#  ['B0876SHMD3', 'B09T6HLFFZ', 'B09T6M1KXJ'],
#  ['B091CRWYXS', 'B09GMHXYQF'],
#  ['B08F45381B', 'B0B783GWZR', 'B08F45381B'],
#  ['B00537P9V0', 'B00537P9ME'],
#  ['B0B1BJXW77', 'B07HCNT5BL'],
#  ['B0BKGKJ7L3',
#   'B0BKGN5VTT',
#   'B0BKGKJ7L3',
#   'B09JJNWNBV',
#   'B09JKDHBSD',
#   'B09JJNWNBV',
#   'B09JKDHBSD',
#   'B09JJNWNBV',
#   'B09JJLLD3Q',
#   'B09JKDHBSD',
#   'B09JJNWNBV',
#   'B09JKDFXTQ',
#   'B09M3WFZVF',
#   'B09MHLJQYW'],
#  ['B01KF3BQD6',
#   'B01KF3JF3Y',
#   'B092D3DGVF',
#   'B092D1Y38Q',
#   'B0953B8NFM',
#   'B09KRNB3TM'],
#  ['B09V7PKRL9', 'B091988QYX', 'B09V7PKRL9', 'B091988QYX', 'B074172SDD'],
#  ['B085VRRHD9', 'B0931VRJT5'],
#  ['B01DSSNNUY', 'B07FDCQ1HB', 'B0918DMMPM', 'B003AYCGGY'],
#  ['1407192124', '1338846620', '1407192167', '1338801910'],
#  ['B0B378B2MC', 'B09YQXYF9S', 'B083RRK4C5'],
#  ['B086HRFHQH', 'B085C7TCTC', 'B08NPR9NFX', 'B09C5K3WMQ'],
#  ['B072XLCZS3', 'B072XM6DBW'],
#  ['B0B2W3NVJ6', 'B0B2VJ391C', 'B0B2W3NVJ6'],
#  ['B08HLVKVWR', 'B00I874D4Q', 'B00OHRT7GA', 'B00OHRTHR4', 'B0B3N6YJCG'],
#  ['B09WCN5KJF', 'B0B6N96KK8'],
#  ['B09DSRD13V', 'B0912KP9VR'],
#  ['B0B7SK4117', 'B0BCKLSWZ5', 'B0B7SK4117', 'B0BCKLSWZ5', 'B01GFQ5ZFC'],
#  ['B08GGC2HSJ', 'B09GGCDBB6', 'B01MU8VESJ', 'B00151WA06'],
#  ['B01BIWKP58', 'B086LLYK4S', 'B07W4DHQJ9'],
#  ['B07ZYTG1TR',
#   'B08DKQHNLV',
#   'B09DK2GMZV',
#   'B08DKQHNLV',
#   'B07ZYTG1TR',
#   'B08DKQHNLV'],
#  ['B00ILNTNLU', 'B00ILNTNLU', 'B00ILNU20G'],
#  ['B01LXS116E', 'B01H2T259U'],
#  ['B07M7L1SLR', 'B0B8Z11W91', 'B09VGKZLLD'],
#  ['B000F7DIHA',
#   'B001949UOI',
#   'B001949UOI',
#   'B07D6RT88H',
#   'B07D6S8PQK',
#   'B07D6RT88H',
#   'B07D6S8PQK'],
#  ['B09VDFC1ZX',
#   'B071YSN3J1',
#   'B09P13HSPM',
#   'B09ZB74X5G',
#   'B09VDFC1ZX',
#   'B071YSN3J1'],
#  ['B094VLF9QV', 'B0B24Z4D3V'],
#  ['B07H5JJJ52', 'B083L5KTX9', 'B081CWWYF9', 'B00YH25IWM'],
#  ['B0912PMWD4', 'B07CHS6GCQ'],
#  ['B0B82L6NLB',
#   'B08TMCB3HH',
#   'B07P6HXKCJ',
#   'B087LV1J5N',
#   'B00161UAJS',
#   'B07Y4W9Q7G',
#   'B07P6HXKCJ',
#   'B00161UAJS'],
#  ['B0BCY8J3N2',
#   'B0B6CF6C2N',
#   'B0BFX2PCSD',
#   'B0BFX2V3TP',
#   'B0B8C8FF81',
#   'B0B42DN2VN',
#   'B0B8T7SSTK',
#   'B0B3MQCTYD'],
#  ['B086VQZ8KC', 'B09CTS2CZX'],
#  ['B08WLQJ8GQ', 'B01AZBTUTU', 'B0168I59WG'],
#  ['B09TPFTGNY', 'B07C21PCCW'],
#  ['B088B5SJZ9', 'B08DHQV5RN', 'B09XLQT92Z'],
#  ['B08ZKYDMT8', 'B073Q4BJKG', 'B08ZKYDMT8', 'B06WD1FD7Y'],
#  ['B0177HKHQK', 'B01HQHGIBY'],
#  ['B093KWXB9R', 'B0B3HS6R57'],
#  ['B0B3TQSRLD', 'B0B3TRC8SF', 'B001EOMZ5E', 'B09B3PN17K'],
#  ['B088QHYVQT', 'B00008D0TV', 'B07CT3JMMQ', 'B086T42MRV'],
#  ['B089C1FL52', 'B088RL6B4F'],
#  ['B08MD23XWZ',
#   'B08V5MWNJS',
#   'B08MD23XWZ',
#   'B0B87PHZZM',
#   'B0B87Q4JM2',
#   'B0B87QK97Q',
#   'B098T7LNZ1',
#   'B098T7LNZ1'],
#  ['B095VKRX2Q', 'B09Z74B8CK', 'B096FJ5XDP', 'B09Z71W5D5'],
#  ['B0B7KJ2T81', 'B08H6KGPX3'],
#  ['B07XF9CP36', 'B08HXQMGRD'],
#  ['B08CN3G4N9', 'B07YF98R2X', 'B08CN3G4N9'],
#  ['B0981F12Q4', 'B0981G55QM'],
#  ['B09FGFNCHS', 'B07HB8PQJT'],
#  ['B07D859X74', 'B07FFTC9FF', 'B07CHZ384Q'],
#  ['B08XWJGYSF', 'B0BFBQNSLJ'],
#  ['B0BCKR74YM', 'B0BCKTQ33H'],
#  ['B09C24NBTG', 'B001326TJA'],
#  ['B0987HNJD5', 'B08DJ313VR', 'B0BB27LM1G', 'B09WYBCC1Y'],
#  ['B08CZJXJ6T', 'B08CZ3T49L', 'B00MHTNZQ8'],
#  ['B0B1WFNKHP', 'B09NBTL7G5'],
#  ['B000SR5OIS', 'B0041BE8G6', 'B08WWRSC8G'],
#  ['B09P4BKWPL', 'B09J1Z2B25', 'B09HSZDWTV', 'B09F6V52PT'],
#  ['B07JZ77R45',
#   'B01BOS3OZ4',
#   'B091G3TW3V',
#   'B00GUXZTOI',
#   'B01LWQ3DQ8',
#   'B00H4IP38U',
#   'B0B28124KT'],
#  ['B004WRKEX0', 'B008FT0QFW'],
#  ['B09P7HX86Y', 'B09P7FGC62'],
#  ['B07F8X6PXJ', 'B08FTF7L9K'],
#  ['B00KXX0YTQ', 'B00104YXIU'],
#  ['B09PQKPKQV', 'B099DFN4M7'],
#  ['B07CM625MR', 'B07CM5G31G', 'B09M7BHR3W'],
#  ['B09XR544ZF',
#   'B0BLBSPLD4',
#   'B0BL8PVSNM',
#   'B0BL8SHFBH',
#   'B0BLBSPLD4',
#   'B08YNBP7RT',
#   'B092D6TVGH',
#   'B09XR544ZF',
#   'B09XR544ZF'],
#  ['B073TXF9GB',
#   'B08XPXGDX2',
#   'B093ZTXGZL',
#   'B09BFQQYKS',
#   'B095RR133S',
#   'B095RTVSQ1'],
#  ['B08FQZPS1J', 'B0B93CQQLV'],
#  ['B08WJSJT4J', 'B08H93GKNJ'],
#  ['B0BHVN91N4', 'B0BHVMQ4WX'],
#  ['B0973RP7H3', 'B08HJWPKGW'],
#  ['B081HJ7K21', 'B0BFJFDTPV'],
#  ['B06XYJCJYD',
#   'B06XYK6G3R',
#   'B06XYJ4PF3',
#   'B06XYDHPRC',
#   'B09DZ121YC',
#   'B078JBHS86'],
#  ['B0989YGYP3', 'B0989YXX55'],
#  ['B088QDFZLN', 'B087R9KK72', 'B09XJDK5YZ', 'B006ZMNWYS'],
#  ['B09L4LQ8B9', 'B0B6T2S6Z5'],
#  ['B07S6MW6C1', 'B0BHZQYB4L', 'B08N676RLR', 'B08N676RLR'],
#  ['B08GTYFC37', 'B08RSML1B8', 'B08HN37XC1', 'B08RX3343D'],
#  ['B013DDMPXK', 'B012G0Y2E6', 'B018P3KPNA'],
#  ['B08W3MZ1RC', 'B0063FZV9Q', 'B08YFDBHLB'],
#  ['B07VFSZNPR', 'B08TLV6YT4', 'B08TM7ZHTQ', 'B08TM5W6ZW', 'B0BBGJDMHW'],
#  ['B08JQ3RPKW', 'B0017TO05Y'],
#  ['B003UOWDCG', 'B003UOWDCG'],
#  ['1846148588', '1846148588'],
#  ['B07PWG318D', 'B079YX4YHY', 'B083Y2D3FG', 'B079YT6D2Y'],
#  ['B07QJ964HP', 'B07QDWWRYD'],
#  ['B08KGSRG84', 'B09F9GLDT4'],
#  ['B09JY8XTBG',
#   'B0941B28YR',
#   'B09RQDZDF7',
#   'B09JXY17B6',
#   'B08MXXYV43',
#   'B08MXXYV43',
#   'B09GBF8X7H',
#   'B004PYD9QE'],
#  ['B01CXX9G88', 'B084ZPM9T8'],
#  ['B07NJCG835', 'B00I8S4W50'],
#  ['B09XJVMBCH',
#   'B09T9P8H35',
#   'B09XJVMBCH',
#   'B09T9P8H35',
#   'B09FPXKJQL',
#   'B0761P8SDY',
#   'B0761P8SDY'],
#  ['B09JBKDSP9',
#   'B09JBDSV7F',
#   'B08KXPF5NK',
#   'B0B8VTC5SG',
#   'B07XJY2WFB',
#   'B01GV9CR7M',
#   '1452182272',
#   'B08XLRHTGH'],
#  ['B099HBQG2W', 'B09BTQSYFG'],
#  ['B082DYJF52',
#   'B082LK6KPY',
#   'B09V9XGY4B',
#   'B09LQL191M',
#   'B093WXJY97',
#   'B08TWZD1H4',
#   'B082LK6KPY',
#   'B082DYJF52',
#   'B0B1MQ93KH',
#   'B0BCYRM4DP',
#   'B0BCYP1YGZ',
#   'B0BCYRM4DP',
#   'B0BCYP1YGZ'],
#  ['B07XMD6L7B',
#   'B08NF9BRK9',
#   'B08NF5JL3F',
#   'B07W7N1QZJ',
#   'B00YTJKL5M',
#   'B00YTJLOLC',
#   'B00YTJL0X4'],
#  ['B00AYXV5W0', 'B00AYXV5W0'],
#  ['B08Z4HXHR7', 'B08Z4KCJZY', 'B08Z4HSBQM'],
#  ['B09B476DD4',
#   'B09B49DXHD',
#   'B09B49YTZ9',
#   'B09B45Z6ZR',
#   'B09B47KLYY',
#   'B09B45Z6ZR'],
#  ['B01NBFTAHE', 'B07ZH9P8QH', 'B082WCXPV5', 'B09VL313PD'],
#  ['B0769WV68W', 'B08YK2RPBZ'],
#  ['B079MW1VVM', 'B086HF9CX7'],
#  ['B089KQJ11V', 'B09XN7BBCB', 'B07HRJB4Z8', 'B09DG63185'],
#  ['B07WVQBD7K',
#   'B07WRFYBDZ',
#   'B08J1X9VVF',
#   'B08J1YMG6V',
#   'B079KJLDF2',
#   'B08J4H9RSW',
#   'B01ARGC2VQ',
#   'B074RCV4HQ'],
#  ['B09TXPXHKC', 'B09XJ77JQX', 'B09TXPXHKC'],
#  ['B0001OZI70', 'B00DEQUB0Q', 'B0001OZI70', 'B00DEQUB0Q', 'B0001OZI70'],
#  ['B07CJLVD1S',
#   'B0060V9FP4',
#   'B092ZB4BP8',
#   'B09NDG4YBR',
#   'B09NDGSM5Z',
#   'B09NDG4YBR',
#   'B08LBGHVRB',
#   'B08LBGSXFZ'],
#  ['B091G31KSJ', 'B0924PV4SK', 'B09TPW1V7R'],
#  ['B0975HXZTH', 'B002XDPTMQ', 'B09H73WJ38'],
#  ['B00DUGZFWY', 'B07JRBW1SF'],
#  ['B0B75TSKKD', 'B08CZYLSFB', 'B07S39CWNM'],
#  ['B092WFZTRB',
#   'B092WH6F8R',
#   'B092WJK1KV',
#   'B092WFZTRB',
#   'B092WJK1KV',
#   'B07R1D55ZN',
#   'B01MYBVZJG'],
#  ['B09XBV1MWQ', 'B07ZJ65HLN', 'B08HQC8JD8'],
#  ['B00NTVJ02Q', 'B07SC2NQBH'],
#  ['B0BCYVCCHW', 'B094316757', 'B07T95HRJM', 'B07T7MDH52'],
#  ['B07ZQMCSGG', 'B07ZQMCSGG'],
#  ['B093D2GNPN', 'B07C8LNSD9'],
#  ['0008535485',
#   '1338714120',
#   'B09XR5WBFC',
#   'B07B7PN3VZ',
#   'B07VWK4JZK',
#   'B08W1H19WK'],
#  ['B09K4GCML2', 'B00BCIRL7Y', 'B07ND9G2TT', 'B07ND9JSQY', 'B00BCIRL7Y'],
#  ['B0999BBMXK', 'B08CDS7C9L', 'B08CDS7C9L', 'B0999BBMXK'],
#  ['B077XXHJXG', 'B07HSK39R3'],
#  ['B08CVV4QCX', 'B08KSMJBWM'],
#  ['B085MW72PG', 'B0B9JC7WS4', 'B0844S6KPD'],
#  ['B0B257NZNG',
#   'B08Z53CDYH',
#   'B0B2598JGW',
#   'B0B259ZHP2',
#   'B0B2598JGW',
#   'B0B259ZHP2',
#   'B09SZR353R',
#   'B00HF63ALI',
#   'B09SZS2DKQ',
#   'B00HF63ALI',
#   'B08QYYX1PW'],
#  ['B09WJZ5NFM', 'B09WJZ5NFM', 'B0B56WDHYL'],
#  ['B089Q1ZCB2',
#   'B0899YQYLP',
#   'B0899W8BBL',
#   'B089Q1ZCB2',
#   'B0058XX3BW',
#   'B004XNLCKW'],
#  ['B09L1DD4DJ', 'B09ZP7YVRW', 'B09ZP1P56F'],
#  ['B00BTGC46C', 'B003672UNE', 'B09GK4ZDXP'],
#  ['B07H72KK7H', 'B07H744FZT'],
#  ['B0B216XS4S', 'B09S79RJN2', 'B09SMG83BT'],
#  ['B09GK4W136', 'B09GK6DPQN', 'B09GK97PC6', 'B09GKFDT58', 'B084ZNYD82'],
#  ['B08CMJVX28', 'B08CMJVX28'],
#  ['B09R2DK96S', 'B082DPGV41'],
#  ['B07KZG6YCW', 'B07K71S5S6', 'B00NW479QO'],
#  ['B0B62TLJK2',
#   'B09X32XPVF',
#   'B08B6G3H9L',
#   'B089QPF4YX',
#   'B0B62TLJK2',
#   'B09X32XPVF',
#   'B0946Q6B9K'],
#  ['B0B6JCFZ9V',
#   'B07SM7B7VR',
#   'B07SNCF2BH',
#   'B07SM8NL5G',
#   'B0B6JCFZ9V',
#   'B0B6JCTLBG',
#   'B0B6P833BW',
#   'B0B6P6F4B2',
#   'B07SM7B7VR',
#   'B07SNCF2BH',
#   'B07SM8NL5G',
#   'B07SNCF2BH',
#   'B07SM8NL5G',
#   'B07SM7B7VR',
#   'B07SM8NL5G',
#   'B07SNCF2BH',
#   'B09DKZH6SZ',
#   'B09TTFY8BD',
#   'B09TPHG111'],
#  ['B085L4THXX', 'B08H1TRGLQ', 'B09FXXPNGK', 'B09FXXPNGK'],
#  ['B07M85RMY7', 'B08YJW16Z1', 'B08YJNMGKM'],
#  ['B07VTR2J4L', 'B086WP3HBD', 'B082HMMBH1', 'B07VTR2J4L'],
#  ['B077V1TRCD', 'B01H8QOZFE', 'B01H8QOZFE'],
#  ['B000KU954M', 'B000KU954M'],
#  ['B0BDYJ3VZ2', 'B01E5KDTZI', 'B07147JJ8T', 'B09RXZ8TZ7'],
#  ['B00EXRER32',
#   'B00BPSCV7G',
#   'B07XG1LCR1',
#   'B07X8SB19T',
#   'B07RZL4MK2',
#   'B0812631L2',
#   'B09J1JD2VK',
#   'B000J6EXLM'],
#  ['B0B4C6KGWM',
#   'B0979ZNFMT',
#   'B0B5TVV631',
#   'B0B87Q9GP7',
#   'B071NMDX8H',
#   'B071NMF1F1',
#   'B09BP93DP8',
#   'B08M58SWB1',
#   'B07QS4QLCT',
#   'B07QPV9Z7X'],
#  ['B07ZKV985Y', 'B07ZKW4BRL', 'B07ZKV985Y', 'B07ZKV985Y', 'B08LNDK2GY'],
#  ['B07CT2NSCH', 'B07CS9D1R6', 'B00JR76TKW', 'B00JR76S2Q', 'B07CT32WPL'],
#  ['B0814VW93R', 'B0814W8GHN', 'B0814VW93R', 'B0814W8GHN', 'B07FPHYLTJ'],
#  ['B09XXDVK65', 'B09XXDVK65', 'B09XXDVK65', 'B09XXDVK65', 'B09XXDVK65'],
#  ['B07CNY7ZKZ', 'B07CNYXQ4W', 'B07CNZHL7Z', 'B07CNYST3N', 'B07CNSZBSR'],
#  ['B075JJ2JBH',
#   'B075JHSJD5',
#   'B075JJ2JBH',
#   'B075JHSJD5',
#   'B09ZVBHWJ9',
#   'B09WNGD9T8',
#   'B09WNHF31G',
#   'B09BW35LFR'],
#  ['B08ZNRCR5Z', 'B07S3X64MC', 'B013WVAHJ2', 'B07S3X64MC'],
#  ['B07KWYGTC6', 'B07KX2N355', 'B00O869QUC', 'B07KX2N355'],
#  ['B00AUSIT2S', 'B00AUSIT2S'],
#  ['1399900722',
#   'B07SKWRL2J',
#   'B01H2STLCU',
#   'B078YXMN3P',
#   'B07M8XQ175',
#   'B08JQDBMHJ',
#   'B0911HVYVJ'],
#  ['B083GN91C9', 'B09QQCZDBX', 'B09QQCWYVQ', 'B07L4D27GK'],
#  ['B09CLHHCRW', 'B09CLFNJQS'],
#  ['B07C8117SR',
#   'B08BR9JD24',
#   'B07C8117SR',
#   'B09GKY6SB4',
#   'B094H97KMB',
#   'B089SSGD8V',
#   'B096W4RJCN'],
#  ['B09V5S8KKV',
#   'B0BFQR2FCW',
#   'B07PNL5STG',
#   'B07PNL5STG',
#   'B08KXPF5NK',
#   'B0BBFK4TJN',
#   'B0BBFK4TJN',
#   'B0B9BQPT23'],
#  ['B09Y3BDQ19', 'B0B1MSS1HQ', 'B07K3H56Z6', 'B000TAT7S2'],
#  ['B08CVPFFQB',
#   'B074XX52Q5',
#   'B08CVPFFQB',
#   'B074XX52Q5',
#   'B01B55X942',
#   'B01KOQQT4K',
#   'B08L9HTGXG'],
#  ['B07Q5CZ6ZK', 'B07Q5CZ6ZK'],
#  ['B09FPXFFM9', 'B07JW5VYWX', 'B07JG4GRJJ', 'B07JFG2364'],
#  ['B00DGPDCWE', 'B00DGPDCWE'],
#  ['B0957J1GJZ', 'B097TFYTXF', 'B0957J1GJZ', 'B097TFYTXF', 'B0B9Y2CHT6'],
#  ['B000OR87U4', 'B000OR6I14', 'B0002H0A3S', 'B000EEL6IW', 'B0002H0A3S'],
#  ['B01L6UATXA', 'B08D3M9469', 'B0B79YVW44', 'B0B78YFBZY'],
#  ['B091DB9TRX', 'B091DB9TRX', 'B08PNT5S3G'],
#  ['B07DD99247', 'B07DD7Y3NT', 'B07DD7JHXC'],
#  ['B08S8L3RZB', 'B07MBZXYMH', 'B00HRRCJW6'],
#  ['B07GXXBD26', 'B06XKNHY2K'],
#  ['B00Q4ZRRZ6', 'B00AZLDCAE', 'B001LK8BRW'],
#  ['B07DV8QH37', 'B07DV5C4W1', 'B0842WDW9T'],
#  ['B09LH36HCX', 'B08CVQLXBC'],
#  ['B095PB79XJ', 'B08PVNVY9V'],
#  ['B0B1L6C8MT', 'B000ZNM51O', 'B07BMNDW7F'],
#  ['B00EKTDJYG',
#   'B003BUDWOC',
#   'B07BJQGV21',
#   'B01M30A9PP',
#   'B00EKTDJYG',
#   'B003BUDWOC',
#   'B00GYZLVEY',
#   'B00EKTDJYG',
#   'B003BUDWOC',
#   'B00EKTDJYG',
#   'B01M30A9PP'],
#  ['B0B1BJFSJX', 'B07VFVRZ6Y', 'B00CL6353A'],
#  ['B07DCZ5WKC',
#   'B07Z8BZD1Z',
#   'B07Z8BZD1Z',
#   'B00KE8I5AA',
#   'B00KE8I5AA',
#   'B00KE8I5AA',
#   'B00KE8I5AA',
#   'B084J4QSKF',
#   'B016MO90GW',
#   'B016MO90GW',
#   'B084DWCZXZ',
#   'B086MYTDHS',
#   'B07K1C7FH2',
#   'B0791F8BBF',
#   'B07FMBMS7J',
#   'B08HM21MN3',
#   'B07HF91VN3',
#   'B0837ZPKDS',
#   'B09TSY6G82'],
#  ['B07P22M2RF', 'B09X5DK7P9', 'B07P488XZY', 'B09FM3RS9G'],
#  ['B009WNG46A',
#   'B08398TW2C',
#   'B07TVSCVTQ',
#   'B08398TW2C',
#   'B07TVSCVTQ',
#   'B089CQ816H',
#   'B07TVSCVTQ',
#   'B00BM4Q1II'],
#  ['B09C874YNC', 'B08CN3G4N9', 'B089Y239L8'],
#  ['B07DBXZZN3', 'B099WRPVJK', 'B07DBXZZN3', 'B07DBXZZN3'],
#  ['B0B4DBMPS2', 'B08CTYW4JV', 'B0B7MXHKHF'],
#  ['B09VKR1598', 'B07GXV3WCV', 'B0051GGBH4'],
#  ['B081Z7YFRL', 'B08YB9KMR8', 'B09P32J7LX', 'B08Z37C4C9'],
#  ['B09VQ7WYNV', 'B09J2XVMFT', 'B09J2XVMFT'],
#  ['B08HQ7VD4Z',
#   'B08DY1FPNM',
#   'B08HQ7VD4Z',
#   'B07WDTY1YW',
#   'B084H89YLC',
#   'B07FSLKMKC',
#   'B082RB6BHC'],
#  ['B00NW479QO', 'B00NW479QO', 'B09THN59MJ'],
#  ['B09D8CZWZQ',
#   'B0B1WMQWG6',
#   'B0BF8N87JS',
#   'B0BF96X3H9',
#   'B0BF8N87JS',
#   'B09BTSM4RH',
#   'B08CDS8KFT',
#   'B07KCH3BV2',
#   'B0B3WMJ5JP',
#   'B0B3WPQNNF',
#   'B0B3WR77XR'],
#  ['B01LXLFF6H', 'B00VYAWIRS', 'B0B5X7HD22', 'B0B5X7HD22'],
#  ['B094D4H1HB',
#   'B003K01BMI',
#   'B08GSDK7DT',
#   'B086VJ88Z6',
#   'B08DF852BK',
#   'B08DF852BK',
#   'B0B2HVD2C7'],
#  ['B00BBWTY0I', 'B004VRQF7A', 'B09SHJGLD4'],
#  ['B08KJKSLG4', 'B01N0Q3CTZ'],
#  ['B0859HN98R', 'B00DCFSTZI'],
#  ['B07N877WD8', 'B077TSCTWY', 'B07N877WD8'],
#  ['B0971NVQTV', 'B08V6V3L2L'],
#  ['B08BG2BZ1W', 'B08BG1RYD9'],
#  ['B0B1TB4N28', 'B097JPW3GH'],
#  ['1911358456', 'B0BCSBHQVN'],
#  ['B077DFCGHD',
#   'B072WBQ5M2',
#   'B09VY8FDLN',
#   'B09VY711HP',
#   'B09VY711HP',
#   'B000LFTYV0'],
#  ['B0B2P9NBX2', 'B08WCYDG64'],
#  ['B071VJD27T', 'B008OT7CL4'],
#  ['B00IL5XY9K', 'B00IL5XY9K'],
#  ['B0B9H936Q8', 'B0B95VNRKW', 'B0B95VNRKW'],
#  ['B07ZFZKJWN',
#   'B086DP28K7',
#   'B07XBPCK6J',
#   'B07X8L2C5Z',
#   'B07ZFZKJWN',
#   'B086DP28K7',
#   'B09TPDPB3D'],
#  ['B0BGLT8TDM', 'B09MTYXBFZ', 'B0993S6SW4'],
#  ['B01DSZHQQE',
#   'B09P46J359',
#   'B08JNLB2BL',
#   'B01M7XTE8O',
#   'B074N3P8B2',
#   'B01MRE8B1I',
#   'B0B4SC7RZ9',
#   'B0B9YF37QG',
#   'B0B9YF37QG',
#   'B00SP30CTS',
#   'B00HF63AYA',
#   'B00SP30CTS',
#   'B00HF63AYA',
#   'B00SP30A0Y'],
#  ['B0001IWDBK', 'B0071QN1AC'],
#  ['B00JFY3AT0', 'B000QHGWJK', 'B001D0YI7M', 'B09QGX2Y8G', 'B09PZ9PFKB'],
#  ['B0912S6MYS',
#   'B0BHXCPS2S',
#   'B091GC8CPX',
#   'B09WDDQP54',
#   'B091GC8CPX',
#   'B093G1V24P',
#   'B08HN17G88',
#   'B086X312F7',
#   'B01DLZE8GM'],
#  ['B09KXVHC79', 'B08TWXWDR9'],
#  ['B07PRZ9XQ5', 'B07PPQP46V', 'B07PPQP46V', 'B07PRZ9XQ5', 'B0859Z1LXL'],
#  ['B07PZW7YWW', 'B084Z1TLR2', 'B07YLKCQZT', 'B08DGPKWWR', 'B018MHR366'],
#  ['B07PQ6HDS4', 'B07PQ6HDS4'],
#  ['B073JFFC2K',
#   'B093W9HR1D',
#   'B073JFFC2K',
#   'B093W9HR1D',
#   'B08YDK4HCN',
#   'B08YDHYD7Q',
#   'B08X45YHQZ',
#   'B08R5KJDYB'],
#  ['B07ZM8PPP3', 'B09DDCQDLH', 'B09DD9YDR1', 'B01N7T7ZRB'],
#  ['B071HRD4DQ',
#   'B0711NM72S',
#   'B0716V18SS',
#   'B071HRD4DQ',
#   'B0716V18SS',
#   'B0711NM72S',
#   'B099HH2QD4',
#   'B099HBQG2W',
#   'B099HD3R3X',
#   'B099HBQG2W'],
#  ['B0B3JSNWRF', 'B0B3JSNWRF'],
#  ['B003HKLQEY', 'B003HKLQEY', 'B00KX0A0VG'],
#  ['B09NHV5Q8Q', 'B09NL4LZPP', 'B09NL3PHHF', 'B09NHV5Q8Q'],
#  ['B078NZL66T', 'B078NZV4T5', 'B08GH72W2K', 'B09QCG9RFX'],
#  ['B07Y5PZCZK', 'B0979H9WSV', 'B09Y93Q98J'],
#  ['B07MFBSQXS', 'B07MHY77GM'],
#  ['B09HSBV93T', 'B08YGFH186'],
#  ['B09BV7YYG3', 'B00AZKNPZC'],
#  ['B09DKNF8CZ',
#   'B00OVD4EA4',
#   'B00NKY0TAE',
#   'B07YCXVMM7',
#   'B01D1Q47DA',
#   'B0848VSCX9',
#   'B01D1Q47DA'],
#  ['B09R1P7QT7', 'B07KD4JYF8', 'B07GWPDKV8'],
#  ['B091L12RBL', 'B084HK4NBH'],
#  ['B0B216XS4S', 'B09NQ1M9T8'],
#  ['B0B586QP6X',
#   'B089PVXLXT',
#   'B088NMVFPD',
#   'B08BLR1X7J',
#   'B09BCZ1RN1',
#   'B08DJ74HNM',
#   'B09ZYG1SS7',
#   'B0B586QP6X',
#   'B09BNQ2DHB'],
#  ['B01K4OQYW4',
#   'B071L9QYTY',
#   'B06VY1KB42',
#   'B09152HXCG',
#   'B084D3TSP8',
#   'B084D3TSP8'],
#  ['B09MLWL625', 'B09MLXV4K5'],
#  ['B00BL5LB2Y', 'B00DDOW9CC', 'B07VT9QX6R', 'B0957139HX', 'B0967JW5RW'],
#  ['B07T6SZL2Y', 'B09QP964R4', 'B09DKDTTVB'],
#  ['B0BFPDF6LG', 'B09RN8M2MK', 'B0BFPG3XCY'],
#  ['B009ODQEBI',
#   'B08V82TD5R',
#   'B07831DCWC',
#   'B0782X9JQG',
#   'B0782XVF9W',
#   'B0782336G9',
#   'B08JHTNLTS',
#   'B01E696NBK',
#   'B002RB1XS8',
#   'B08DG535HG',
#   'B08DG5SRSS',
#   'B09SLSFV8V',
#   'B00H463226',
#   'B003PK1DIA',
#   'B00X9U9AA4',
#   'B08V82TD5R',
#   'B08DG535HG',
#   'B08DG5SRSS',
#   'B09SLSFV8V',
#   'B09SVLSKM2',
#   'B09SLSFV8V',
#   'B08DG535HG',
#   'B08DG5SRSS',
#   'B09SVLSKM2',
#   'B08DGPKWWR',
#   'B079ZZXJLJ'],
#  ['B07GRNTBCF', 'B09SW6NCF9', 'B091L5MTQ6', 'B07GQX4C5B'],
#  ['B00LQTEO5G', 'B075XPQ5FR'],
#  ['B073S7D1G3',
#   'B01K9FQ3JC',
#   'B01K9FPZAU',
#   'B01G6N4JWE',
#   'B073S7D1G3',
#   'B073S7D1G3',
#   'B00BBLDDQK',
#   'B000ZQ86WI'],
#  ['B0B641PGY2', 'B07RTSHBV9'],
#  ['B07CRT4BDW',
#   'B009IK5MEW',
#   'B08VWB4YKC',
#   'B08VW6DHWW',
#   'B08VW515QD',
#   'B08VWB4YKC'],
#  ['B09YKZJFL3', 'B085L61X9R'],
#  ['B071CPT89Z', 'B07B4NQTJ2', 'B07B4NQTJ2'],
#  ['B08PG1KPQ7', 'B09H7DKF1M', 'B07DHMP9XV'],
#  ['B08J3WXJDH', 'B08J3WXJDH'],
#  ['B08MB72F45', 'B07MJ9NSCK'],
#  ['B0852VJ6RD', 'B0852VJ6RD', 'B0B7Y11JST'],
#  ['B0733Q3Y4P', 'B0733Q3Y4P'],
#  ['B08Z9Y7VTC', 'B094VBHQGP', 'B09DQ79C3Q', 'B00WU5VGLK'],
#  ['B017SYX4A8', 'B09Z2DY7BS', 'B000LFXDVW'],
#  ['B08GJF93VL', 'B076MYDNNN'],
#  ['B0BKQXGVQ1', 'B0BKQXGVQ1'],
#  ['B09J3DFNPF', 'B086C7WJXY', 'B00FLPF4YG', 'B089VYQGQW', 'B09JKXH89C'],
#  ['B08CB6WVZL', 'B08ZHY6M7C', 'B099DXDGPX', 'B08FZC6RBK'],
#  ['B085FK2T7D', 'B00OGMTNT2'],
#  ['B082VLKQD8', 'B07SB635ZK', 'B0798NX3LK'],
#  ['B0847JDJ6X',
#   'B097QR3DH9',
#   'B09G644F7T',
#   'B09LLPBPT6',
#   'B0847JDJ6X',
#   'B0777FQCQH',
#   'B09LD13FNL',
#   'B09LD8NJ8D',
#   'B07Z698G9J'],
#  ['B07FQSMFRN', 'B07FQRT5QH', 'B0895RB4YC', 'B07X4H78H4', 'B01985N4T6'],
#  ['B097C3QMDS', 'B08MLJK563'],
#  ['B07RYSDKRM', 'B086N2Y82P', 'B086N4B878'],
#  ['B09MZGF1Y8', 'B07RKN5N43', 'B07WMWTSB3', 'B07WMY1JXM', 'B07WMSYSM5'],
#  ['B07YYW1H55', 'B08LKZ6VDK'],
#  ['B073XNK45P', 'B07F6DHHB1', 'B08L9NRCJJ', 'B077GZ3TVS', 'B09BNZWPZY'],
#  ['B082VQFZSH', 'B07KYJMYGF', 'B08Y7PTKG1'],
#  ['B09W7TBGN9', 'B09Z8K51QG', 'B07Y1QKLQC', 'B092R8K6C9'],
#  ['B0B5QTLMTR', 'B082YCXZXP', 'B0812FT4DR', 'B0812ZV434', 'B0812GHH1L'],
#  ['B07KZW31RX',
#   'B07CV8R7XR',
#   'B07CV8R7XR',
#   'B07KZW31RX',
#   'B0B6PH89VX',
#   'B09FP8TDP9',
#   'B07KZW31RX',
#   'B07CV8R7XR',
#   'B09XZQWY77',
#   'B09XZD7CCB',
#   'B001DQESXA'],
#  ['B01GFKOKKO', 'B004EAIWHA'],
#  ['B09C8YDPYY', 'B07W4KSKXZ'],
#  ['B08ZJLNYZG', 'B007FASP28', 'B09GK8P162', 'B00VPXHMG6', 'B09GK8P162'],
#  ['B00F9H1ERW', 'B00F9H1GHA'],
#  ['B0B1JMRDWK', 'B07VM1HQDJ'],
#  ['B091BMHTR6', 'B0845CGJFW'],
#  ['B07HHYNYYS', 'B07RDFP4NW', 'B07HHYNYYS'],
#  ['B0B5WH6Z1D', 'B09CKGPB2B', 'B099S2WQSW'],
#  ['B08R4YSHR5', 'B08R4VNTM6'],
#  ['B000V0AL80', 'B01HYFNA50'],
#  ['B07QM7RYF4',
#   'B09G9PMQJ2',
#   'B092MFWPTT',
#   'B085DRJV4N',
#   'B085DDJCNL',
#   'B019QNK7OA',
#   '0141376104',
#   '0241357799',
#   '024135739X',
#   'B0813XHQGR'],
#  ['B0BCY5M2TD', 'B0B74YJLR5'],
#  ['B0B8V187N7', 'B09DGGR191', 'B00O6Y20U4'],
#  ['B0BHDSVFB2', 'B079ND1QXR'],
#  ['B07RPCQX25', 'B073FJ3B77'],
#  ['B07L3XJ75Q', 'B07L3XJ75Q'],
#  ['B000KU54WY', 'B000KU9434', 'B014DEGPGG'],
#  ['B0987X8KT5',
#   'B0987T46X7',
#   'B01BF6F20K',
#   'B0987T46X7',
#   'B08KZXQF8N',
#   'B08KZXQF8N'],
#  ['B09MG2K7M6',
#   'B077B9X3SB',
#   'B07N8QY3YH',
#   'B0936FGLQS',
#   'B07N8QY3YH',
#   'B08L6TR7YM',
#   'B07N8QY3YH',
#   'B09QT4LR97',
#   'B077B9X3SB',
#   'B077B9X3SB',
#   'B07X4YNHHW'],
#  ['B08J3QYWT4', 'B0827M4WG2', 'B0827M4WG2', 'B000B6FBA2', 'B0037MA69I'],
#  ['B00CYHL46G', 'B004UA62B2', 'B09HKXMBM5'],
#  ['B084VPR3N2', '0751579955', '0751584207'],
#  ['B0741FFT6F', 'B016ZWXYXG', 'B0741FFT6F', 'B0741FFT6F'],
#  ['B08DCFHBNF', 'B09H6LCPQP'],
#  ['B0B76PNY4S',
#   'B09KC516PG',
#   'B09T6HLFFZ',
#   'B09T6M1KXJ',
#   'B096P2VPDF',
#   'B08Q83BC7L',
#   'B08Q7WG4TD'],
#  ['B0B256HNBW', 'B08CDB4YZG', 'B0B24SG4YR'],
#  ['B0BGL639T1', 'B07SCJ8P3W'],
#  ['B09TWBJQ5K', 'B0829R19YZ', 'B08MW7F2GL', 'B08N4BSQJL'],
#  ['B09XFTHTJG', 'B09XFTHTJG'],
#  ['B09LDBZ3RZ', 'B00CM6YYCU', 'B003AYCGGY'],
#  ['B08YQRQHFN', 'B09LZ7BY9P'],
#  ['B09KVJGYDY', 'B0788R2R1N'],
#  ['B076611KCY', 'B08KQF2NH8', 'B00BAKN5TC'],
#  ['B088PFM9VV', 'B088PG6NG9', 'B08P4Q3R94', 'B08P4PLLYC'],
#  ['B08M5GLWSN', 'B07VPSSKVW', 'B09W5KWYR6', 'B08M5GLWSN'],
#  ['B08FR3HN42', 'B08FQY1WDV', 'B08FQRFZS2', 'B08FR3HN42'],
#  ['B01D8XKKAK', 'B01D8XKK78', 'B01D8XKKAK', 'B01D8XKK78', 'B01D8XKKAK'],
#  ['B07WNJWTTL', 'B07WVM23Z9'],
#  ['B07MBBFYRP', 'B07MBBFYRP'],
#  ['B09MQKHZ5S', 'B09MQKMNHN'],
#  ['B08S5FD5F7', 'B08S5FD5F7', 'B082MJ32FK'],
#  ['B07GDDG5TF',
#   'B007VAKT3A',
#   'B007VAKTLC',
#   'B00ZUNQOLG',
#   'B000C74ZPW',
#   'B007VAKR5A',
#   'B007VAKTLC'],
#  ['B09BZBYM4H', 'B09GLW1HC6', 'B09BZBYM4H', 'B09BZDX9FX', 'B089W3P1XY'],
#  ['B07V4MPGGY', 'B0023NU5F2', 'B07BG6D8SV', 'B0002EXYP2'],
#  ['B099TF3Y2M', 'B099T1XD8V'],
#  ['B07FMWYL64', 'B07ZV31J31'],
#  ['B00119Q8RI', 'B01K8RYA1O', 'B07WCCK6BC'],
#  ['B07MSJCPR4', 'B07QZ9NN13', 'B07MSJCPR4', 'B00KGOM6C0'],
#  ['B079VPK9GV', 'B019IJZZCQ'],
#  ['B08JTVBNNN', 'B08TWZCZZ2'],
#  ['B085GDPKLY',
#   'B085FSW26T',
#   'B09MVRS9NP',
#   'B09MVR2R8X',
#   'B07VC3ZW9W',
#   'B07V7G9968',
#   'B0BDJ47W5B',
#   'B0BDJ61GFY',
#   'B09G997T36',
#   'B07DRLN9YV',
#   'B09MVRS9NP',
#   'B09MVR2R8X',
#   'B07VC3ZW9W',
#   'B07V7G9968',
#   'B07VC3ZW9W',
#   'B07V7G9968',
#   'B07V7G9968',
#   'B07V9J83LJ'],
#  ['B08BYHSKMX', 'B08BYJ2J6S', 'B08LY4G57M', 'B088RGZLMY', 'B09MZ25XXW'],
#  ['B09PGZ81J6', 'B09B36YF1R', 'B09TW22283'],
#  ['B07WX16Z34', 'B09Z25GDX3'],
#  ['B0B8M6DSTV',
#   'B0B8M6DSTV',
#   'B0866P5J22',
#   'B09TQRRMJ3',
#   'B09TDD4H8N',
#   'B09K7G4P2Y',
#   'B09TDD4H8N',
#   'B0B971DJGM',
#   'B0B974BHJF',
#   'B0BD6C5Q7F'],
#  ['B099DQXDT8', 'B09C83H6HD'],
#  ['B0B9RTFWZD', 'B0B8CB37NS'],
#  ['B0B6JTHFWJ', 'B08P1YZD91'],
#  ['B08R4ZB1MZ', 'B08R4VNTM6', 'B01AT1A9PK', 'B00694X030'],
#  ['B08P2NWJBH', 'B08NXCTDVL'],
#  ['B07G3WRXMV', 'B07G3WRXMV'],
#  ['B01760A8R6', 'B01760A7PY', 'B084MKY4X2'],
#  ['B074FP14XP',
#   'B00NXZSOB6',
#   'B074FP14XP',
#   'B074FP14XP',
#   'B00NXZSOB6',
#   'B089C1FL7K'],
#  ['B07KYH43TP', 'B08K35L4RL'],
#  ['B08GLH577Y', 'B08GLHY3JD'],
#  ['B09D4SZL87', 'B09D55GFR2'],
#  ['B0872HRW25', 'B09L63GT57', 'B09L63DM2P'],
#  ['B0B9HB2XSL',
#   'B0B9HDRL3C',
#   'B09BZTZ59L',
#   'B0B9HB2XSL',
#   'B088P13VKP',
#   'B09XRCSBLN',
#   'B09BZTZ59L',
#   'B09BZVB63Q',
#   'B0933LVCV4'],
#  ['B00KU7RBLO', 'B00KU7RBLO', 'B00KU7RBLO'],
#  ['B07L3S2XLB', 'B07L3S2XLB'],
#  ['B00CBU0IV8', 'B09FSPJ9F7', 'B074PQVNYN', 'B078T2NTJ8'],
#  ['B08J7GDQ8C', 'B09GKG1LWF', 'B07ZFGR1B3', 'B09GKFSL2C'],
#  ['B09JFLS2VK', 'B09N8M646K', 'B09N8Y7RSM', 'B09PTF17TR'],
#  ['B014UU7XCI', 'B085NLN9N5'],
#  ['B0B4RVBBRG',
#   'B0B8Z3CLKF',
#   'B09XDN5LMV',
#   'B0B8Z3CLKF',
#   'B09NXQK2ZM',
#   'B09XGS2QZT',
#   'B09NXQK2ZM',
#   'B09XGS2QZT'],
#  ['B09B7LK9WF', 'B09H1ZN75M'],
#  ['B0B58G3VTL', 'B08CXP3WQB', 'B0B9GW36KV', 'B08CXP3WQB'],
#  ['B07GCGJBC1', 'B0BDL81Q4D', 'B0B1CXW5P1', 'B098S76LSF'],
#  ['B0B6ZP88ZQ', 'B0B6ZJ9WPP'],
#  ['B085WV8R86', 'B0B1BRKW1X', 'B09PF7Y7C8', 'B08WWWGJR6', 'B09F423Y2B'],
#  ['B0B7RNGFBT', 'B0B97JY79L', 'B0B97K9WQ9', 'B0BBZBXLXD', 'B0BBYR7JVM'],
#  ['B099ZZ4FTX', 'B007087XOQ'],
#  ['B08ZHZMMHR', 'B08PCP9PTC'],
#  ['B077V37F17',
#   'B077V7Z12Z',
#   'B077V37F17',
#   'B077V2MXP6',
#   'B09YLRS25J',
#   'B09J4QCK9X',
#   'B09DZ121YC',
#   'B078JBHS86',
#   'B08HY1HYHL',
#   'B09DYW2BF4',
#   'B08HY1HYHL',
#   'B09DZ121YC',
#   'B08PZD9Y4B',
#   'B08PZ9WDR7',
#   'B08PZD9Y4B'],
#  ['B00Z70I1HW', 'B09843Q92N', 'B01LQ6TXLS'],
#  ['B072LW883H', 'B0728HL3C3', 'B06XKM15KM', 'B09HHHT8QR', 'B07YX4N2YV'],
#  ['B08X6ZBZ43',
#   'B094ZK1ZW3',
#   'B09CCNXFN4',
#   'B09MVW2CXY',
#   'B07MJ75VBT',
#   'B08WJBKVCM'],
#  ['B07NQKTVH5', 'B072MDB9H4', 'B07T8FQ165'],
#  ['0241538203', 'B09VH2MRDD', 'B08YY97GX5'],
#  ['B08WQ6KP1W', '1405950684', 'B08181DPHX', 'B08WQ6KP1W'],
#  ['B085B23JHC',
#   'B00009R61B',
#   'B08PBWTFZZ',
#   'B0824SPBZ9',
#   'B08NJQGFDX',
#   'B00IUAAK2A'],
#  ['B09BNTQFHH',
#   'B08G4P1N3N',
#   'B09QFX2144',
#   'B09QG1W72R',
#   'B09RGMJWL3',
#   'B09QFK7QRC',
#   'B09BNVHQ2C',
#   'B09FY8ZBKY',
#   'B09QG1W72R',
#   'B09QG1W72R',
#   'B09BNVHQ2C',
#   'B09FY8ZBKY',
#   'B09FY8ZBKY'],
#  ['B003TL3W6Q', 'B003TL3W6Q', 'B015WYGI40', 'B08JYFQ5ML', 'B004US3F1Y'],
#  ['B07D7GKXYM', 'B07MDMZHTB', 'B07D7GKXYM', 'B07D7GKXYM'],
#  ['B0777NR8KQ', 'B07VG9B39B'],
#  ['B09CFP6NRM', 'B08F1XYZD7', 'B09D9RP5WS'],
#  ['B0B5XP78LK', 'B0B5LMQH28', 'B0B7H8X7NF', 'B0B7H8X7NF'],
#  ['B0B7M4CG5L', 'B09YGPP75T'],
#  ['B06X3VQRC7', 'B06X3VQRC7', 'B08C2K6TLH', 'B06X3VQRC7'],
#  ['B09GVB1JXC', 'B0BDYSHRQH'],
#  ['B071WWK11X', 'B0721BP22P', 'B09GVXWWQY', 'B0B1V7B6NJ'],
#  ['B0BJV8XM2W', '0857504797', 'B01M359WDC', 'B071Z3KFXD'],
#  ['B09P4XJB14', 'B0BBY87Q51', 'B09S9PZ8Q8', 'B09QMJ4ZRN'],
#  ['B096HKQK9W',
#   'B09VCRS7ZQ',
#   'B096HJB3GF',
#   'B096HGD3BK',
#   'B096HKQK9W',
#   'B096H6ZM74'],
#  ['B07DLGZ828', 'B07DLDLL3P'],
#  ['B07WRQBTFT', 'B09PGGC92W', 'B09PGJ7SR3'],
#  ['B005CNVFGI', 'B0BJKCF1H9', 'B09M75NFTF'],
#  ['B09GG3HFBJ',
#   'B09NRNVX6L',
#   'B084YXK293',
#   'B0B1BRWWL3',
#   'B08T5TRTJ5',
#   'B0B1BJBDRV'],
#  ['B00KB1YRH0', 'B08FXPJC6F', 'B000J63AIO'],
#  ['B095NPZ8LW', 'B095RW8NXJ'],
#  ['B00LAI9OM6', 'B00EJXIZ60', 'B0088LIINY', 'B00BSYR7K8', 'B00LAI9OM6'],
#  ['B0038XBOJC', 'B08LDRRDQZ', '0008532966', '0008321531', 'B01NCECCWS'],
#  ['B08W9S7LJ9', 'B09Q952HDC'],
#  ['B07BJMNGTP', 'B09FJVLZYF'],
#  ['B00BBPYSHY', 'B00V50YXIO', 'B07PBBYV8K'],
#  ['B07CRG94G3', 'B07CRGSR16'],
#  ['B081QGYR4T', 'B081QJ24HH'],
#  ['B09PN1ZKQ4', 'B07P5TG1K7', 'B08H85LK4H', 'B07P9V36D8'],
#  ['B079434K23', 'B0924RZZ2B'],
#  ['B09KRQ5VHQ', 'B09MHTM3NW', 'B09ZTG58W5', 'B0B5SP6JKK'],
#  ['B0B1PP4JFH', 'B09FPSQWKJ'],
#  ['B091BV98VZ', 'B00LA29QA2'],
#  ['B07GQ39GLL', 'B07GQ8ZVGM', 'B07YBLDNNR'],
#  ['B09DSXB1TJ', 'B09DVKKW25', 'B097Q36LZQ'],
#  ['B09X1RR4D8', 'B08V7LFXW2'],
#  ['B00IZD2MDM', 'B00IZD2MDM'],
#  ['B000OLDX4U', 'B07S2F1LQN', 'B000OL8CT6'],
#  ['B0954HFXTN',
#   'B0954T1CQG',
#   'B08TDYB43D',
#   'B08TDYB43D',
#   'B09J4GQFQZ',
#   'B09J4GQFQZ'],
#  ['B00I506718', 'B01KM2IG9W'],
#  ['B084LGXN51', 'B084LGXN51'],
#  ['B07CCNBRWH', 'B07C8ZT8J4'],
#  ['B08L9RRNY5', 'B08J4NMBL2', 'B0B5H16QP9', 'B08YYCS15W', 'B0B5H16QP9'],
#  ['B0722JMW6T',
#   'B07G2BCKCV',
#   'B09STFJ4BF',
#   'B07CM83YV8',
#   'B08JGQJGTC',
#   'B08YRNJQ56'],
#  ['B08DL5M52T', 'B00I8S4W50'],
#  ['0552565970', 'B08GWS298V', 'B094YGC53R'],
#  ['B095LVRJBR', 'B0BCZ6594F'],
#  ['B0BGNJ9VW9', 'B08XMLHXZD', 'B0881JKBL8'],
#  ['B08CCTBWHS', 'B085KPH4Y9'],
#  ['B075F981G1',
#   'B0BKW31VTB',
#   'B09QFN2DYJ',
#   'B0B6ZP6LKS',
#   'B09B7J61GW',
#   'B09LHFB5WN'],
#  ['B08MQ4M1LC', 'B00BRYZK9E'],
#  ['B00T698SWS', 'B003VVU6L8', 'B00T698SWS'],
#  ['B089QXS8BM', 'B089R19WXL', 'B089R11H3L'],
#  ['B09PD1RP5Z', 'B091CNQMN9'],
#  ['B07VJ5DDT7', 'B01E9F27J8'],
#  ['B091TXXWXS',
#   'B0733CKYSS',
#   'B08HS8QJML',
#   'B08KY9MR55',
#   'B08KY9MR55',
#   'B08M9RL3NS',
#   'B08139PLS1',
#   'B07PFHN8KV',
#   'B08K375P7Z',
#   'B07XYVCLLL',
#   'B08K375P7Z',
#   'B08NGBBFVX',
#   'B07PQ6KK74'],
#  ['B078962XG1', 'B09K7W2RNQ', 'B07894CSCZ'],
#  ['B0BK18LXCS', 'B0BJ1MDL8Y', 'B0BK18LXCS'],
#  ['B08FMMLGTS',
#   'B00OP26T4K',
#   'B09L4TM4QB',
#   'B0987WF6X1',
#   'B00ER445UQ',
#   'B07HGWC6PB',
#   'B07W7YZXR6'],
#  ['B08Y1SPW9G', 'B01M8JT6FT'],
#  ['B09YYTX5NV',
#   'B08KSGPG54',
#   'B08MFJ3YT1',
#   'B0BB2DBSTJ',
#   'B0BB2C3N58',
#   'B08KJP217D',
#   'B08B6THQX9',
#   'B0BB2DBSTJ',
#   'B0BB2C3N58'],
#  ['B07GJVWHD4', 'B09D3B2Y5V'],
#  ['B08VBF1LLY', 'B094C54HP6'],
#  ['B08B8R6S86', 'B08B8S4BHD', 'B08H21WB9M'],
#  ['B0B1BGWXJX',
#   'B08W5GYF6T',
#   'B09RGD6XNN',
#   'B09W1V99ZG',
#   'B08G44DS1X',
#   'B0BFPBZLCG',
#   'B09QFZXWDQ',
#   'B09DDB3NKS',
#   'B08W5FXSQJ',
#   'B09KCRJMRK',
#   'B08W5FF49K'],
#  ['B08KGFW3JT',
#   'B07Z8374BX',
#   'B0B7XD12J5',
#   'B0B7XDYQVR',
#   'B07Y66ZVN7',
#   'B076CDFQKS'],
#  ['B09JW3FCQ6', 'B09S2RTFM2'],
#  ['B07YL6Q4KH', 'B08DJ35VQ1', 'B09TT7GQ25'],
#  ['B07S98ZM34', 'B07S98ZM34', 'B09771JR5W'],
#  ['B06XDNR6RN', 'B06XDNR6RN', 'B06XDNR6RN'],
#  ['B0002HOV6K', 'B000YJEQMK'],
#  ['B08DRB6P42', 'B08DQY6DYP', 'B09YHWZT8N', 'B09YHZ1XKJ', 'B071L47LP5'],
#  ['B085XVFTJD', 'B085XVSK87'],
#  ['B08MF6YV2B', 'B00AU1VCII', 'B081B81MM9', 'B006ZN1LMC'],
#  ['0241333113', 'B09GXQ16CH'],
#  ['B003TCPTIY', 'B003TCPTIY', 'B003TCPTIY'],
#  ['B000ORQY0E', 'B0027SU58A'],
#  ['B09JRP6GR9',
#   'B09JRTH35J',
#   'B095PPVZQG',
#   'B095PSBBKQ',
#   'B09JRP6GR9',
#   'B09JRTH35J',
#   'B09YYG2JP1',
#   'B09RSQH4GP'],
#  ['B0046QF3H4', 'B00P1LKQ0M', 'B00P1LKQ0M'],
#  ['B007K5XZXM', 'B0B6CB992N', 'B007K5XZXM', 'B09NK2PFGV'],
#  ['B000X1P204', 'B009B5GYP0'],
#  ['B0865RL4PH', 'B08TV24K42'],
#  ['1783446803', '1783446803'],
#  ['B073BDH6GR', 'B0B265MNTK', 'B0B25VSDVB'],
#  ['B07D538VGH', 'B07D54BKXS', 'B08MZCX8XC'],
#  ['B09PV6Y699', 'B09PV7QYDF'],
#  ['B089DNM8LR', 'B08TJ2649W'],
#  ['B087LSZF4M', 'B07PG2HRKS', 'B07T6C9827'],
#  ['B095PCGTVF', 'B09C893L6C'],
#  ['B09SBXYGGN', 'B0BFTDNRJL', 'B09FTGHP5Z'],
#  ['B0843T7TL4', 'B08ZYZ1PWX'],
#  ['B00NABTC8M', 'B00LWFFA4S'],
#  ['B00HXDGPA6', 'B00HXDGP4M'],
#  ['B085WV367W',
#   'B09F423Y2B',
#   'B085WV367W',
#   'B07W6QBJ84',
#   'B09BNX183W',
#   'B08G4GVRD8',
#   'B09BJWCYYQ',
#   'B08W9R46CW'],
#  ['B00C9FSGEG',
#   'B09KGRPR8V',
#   'B082HT85YB',
#   'B082HV6LQJ',
#   'B09KG1VR2X',
#   'B082HV6LQJ'],
#  ['B08WPSD9PY', 'B07649WV5Y'],
#  ['B08GLGJJ81', 'B078LXDKVD'],
#  ['B08BLBZVT4', 'B07H8P9JNM'],
#  ['B09D7NR6VC', 'B07V5TNCKH', 'B09D7NR6VC'],
#  ['B07V7P3Q7S',
#   'B009TU4XBY',
#   'B09YVGPKLK',
#   'B09YVDRS4K',
#   'B0BDVTMWH3',
#   'B0BDVVMR9S',
#   'B09YVGBK4B',
#   'B09YVGPKLK',
#   'B00DDSJQSI'],
#  ['B09PF7Y7C8', 'B08WWWGJR6', 'B09XJCJH57'],
#  ['B08GP35C22',
#   'B07CSXPJRN',
#   'B07LH4DVW7',
#   'B096XS5H2G',
#   'B096ZH8PF2',
#   'B09535KYXB',
#   'B09535PJ34'],
#  ['B0B2V4YKPK', 'B0B2VYKBMW'],
#  ['B089X93SGD',
#   'B092C5HJ9Q',
#   'B0B67LD6MS',
#   'B07CYQ8KFS',
#   'B094V794QF',
#   'B0714KVG4L',
#   'B0714KVG4L',
#   'B0B8HYGWSL',
#   'B0B9G13LDY',
#   'B089X93SGD',
#   'B0068FMNDI',
#   'B0842YLJD9',
#   'B0842YNRWG',
#   'B0842YLJD9',
#   'B0842Y842F',
#   'B00QYOSKH6',
#   'B0842YNRWG',
#   'B0B67LD6MS'],
#  ['B09BCG9Z17', 'B09Q6FBR25'],
#  ['B083QGP9KR', 'B09MW98L98', 'B0B2WKBW6X'],
#  ['B01AXOOZTY', 'B00MO90546'],
#  ['B07H1VGLZH', 'B07H1VGLZH'],
#  ['B08NP8ZC52',
#   'B08NP71RPG',
#   'B09YXPSHS4',
#   'B09YXTRQXY',
#   'B07XBKVLXC',
#   'B0B58RXW35'],
#  ['B08HJ2GWPY',
#   'B0155N6RYE',
#   'B09WMGG84T',
#   'B076B3Q8JR',
#   'B07DHK5DHN',
#   'B076B3Q8JR',
#   'B07DHK5DHN',
#   'B07DHK5DHN',
#   'B09F3RNDM7',
#   'B08J7QJW37',
#   'B09F3M5SM6',
#   'B08J7RB8YV',
#   'B08XB451LH'],
#  ['B0BH3WCX4V', 'B003H1CWPU'],
#  ['B07JGMPFJQ', 'B0B1J1GG9T'],
#  ['B01DYBQK2I', 'B098KLC533'],
#  ['B09XJTM8TH', 'B09XJTMG83'],
#  ['B0B7CN5R34', 'B071W16RVC', 'B071W17498'],
#  ['B07VP5BKSW', 'B095J8R9Y2'],
#  ['0008326045',
#   '0007423705',
#   '0007977174',
#   '0007977174',
#   '0008413266',
#   '1529087058',
#   '1529087058',
#   '1405950242',
#   '0241533996',
#   '1405950242',
#   '0241533996'],
#  ['B094VJV1ND', 'B09MQ7SL4F', 'B08XMC9N2Y', 'B08XMLGZ5G', 'B08XMFFFWH'],
#  ['B0B7MHJ2WN', 'B0B7MHJ2WN'],
#  ['B09JVPR7YT', 'B09JVTD7G2'],
#  ['B0B1VKN458',
#   'B0BHNTWSQ7',
#   'B0B3D4TBRM',
#   'B09V7YTQ67',
#   'B0939XMQYT',
#   'B099KFD7W3',
#   'B096V1GXPK',
#   'B0B25QSYM2',
#   'B09DFZ9KKL'],
#  ['B07SM7B7VR',
#   'B07SNCF2BH',
#   'B07SM8NL5G',
#   'B07WJJ3SF7',
#   'B07K4FGLMS',
#   'B09KS87CR1',
#   'B07K47BG6K',
#   'B0B55QHZM8'],
#  ['B09L1H978W', 'B088X2W12Y', 'B088X3V6JT', 'B088X3XWY2'],
#  ['B003K1FXTO',
#   'B07D47N9J6',
#   'B08D9RLYSY',
#   'B003ZY9Z40',
#   'B003K1FXTO',
#   'B003ZY9Z40',
#   'B07PPGWQ15'],
#  ['B09KS9JPD4', 'B08R4VNQKT', 'B006L6736G'],
#  ['B09ZLHF664', 'B07X7KDS6Y', 'B08CZCNYWZ', 'B09ZLHF664'],
#  ['B08CDQMBQ2', 'B07YV2SQYP', 'B08CXMS6TD'],
#  ['B07BLRR3VS',
#   'B07C8PPSW8',
#   'B07BLQNFCQ',
#   'B07BLRHQ4B',
#   'B08XQVJ4FP',
#   'B09TFWDQSL'],
#  ['B0BCQTQTQ7', 'B079QBXBWB'],
#  ['B0B67QCZ65', 'B09KL55WKZ', 'B09R4F3TRD'],
#  ['B0B9HKZ995',
#   'B09X2WXT9L',
#   'B09X2Z852B',
#   'B09X2WXT9L',
#   'B08H1BDG2P',
#   'B09BCPC3MN'],
#  ['B005BNMWQQ', 'B0B54VFNRN'],
#  ['B07ZGDK9L5', 'B0001GYNJM'],
#  ['B08R44GH1Y', 'B07SJH9NWK'],
#  ['B09KR89ZMM', 'B08C1RR8JM', 'B07ZZW7QCM', 'B08C1RR8JM', 'B091G31KSJ'],
#  ['B09XGRY7QQ', 'B095Y5VZKR', 'B0B774XCJG'],
#  ['B0781DFDTP', 'B07G5SG3SS', 'B07L5WGS2X'],
#  ['B09G3D1KBL',
#   'B09G3C4PF7',
#   'B08XFFLB76',
#   'B01F7B2VJ4',
#   'B01F7B2S7E',
#   'B09CQDGCMM',
#   'B09SGN9GMX',
#   'B01F7B2S9C',
#   'B0B5RPH4M7',
#   'B0B5RTPDXZ',
#   'B0B5RTBHRN'],
#  ['B08D3KYG5X', 'B08K2V6W55'],
#  ['B08DDYLKGS',
#   'B09CLGK3MQ',
#   'B097DWYF66',
#   'B09FGQ9BCY',
#   'B09BF148DX',
#   'B087CNBPX1'],
#  ['B07X4YNHHW', 'B001G7STT0', 'B00DOJG6RA'],
#  ['B009IK63RC', 'B000Y1AZ1Y', 'B01HSUQ8IC', 'B08M883QW3', 'B08M83HF18'],
#  ['B005Q7B59W', 'B005CGUI8G'],
#  ['B0765ZQJYJ', 'B0765YZN47'],
#  ['B08DFSY5QB', 'B08CMFY59D', 'B0762ZS95D'],
#  ['0241003008', '0140569324', '0702315001', '0723258597', '1509830391'],
#  ['0140167773', '0241995345', '0241989523', '0241989523'],
#  ['B019FCE74I', 'B000NMAOYM'],
#  ['B08TPHWK15',
#   'B07B9K6MFT',
#   'B08TPHWK15',
#   'B06X3W7GS4',
#   'B01EFF4Y3Y',
#   'B06X3W7GS4',
#   'B07L9W1RHZ',
#   'B08FM5P2LW',
#   'B07WXH7HY9'],
#  ['B0BDKH4BBQ', 'B0BDK4BZW1'],
#  ['B009SK9CTS',
#   'B009Q8492W',
#   'B081S1N1JS',
#   'B06ZZDRCDW',
#   'B009SKHAOC',
#   'B081S1N1JS',
#   'B009Q8492W',
#   'B06ZZDRCDW',
#   'B009SKHAOC',
#   'B009SK9CTS',
#   'B01N5MBE36',
#   'B00JR9I2KU'],
#  ['B0B5S48XK5', 'B078HRXTXM'],
#  ['B09KRHF2XD', 'B09KRKFHQ8', 'B0797T2RSM', 'B099DG6SW9'],
#  ['B0746QVBR8', 'B0746QVBR8'],
#  ['B09MT3834H',
#   'B09MT41RY4',
#   'B09MT3CM1G',
#   'B09Y8CJ5TF',
#   'B09Y89CMG8',
#   'B0B3MJHH2B',
#   'B09ST6ZZQY',
#   'B09XK6WKTB',
#   'B0991Z93GL',
#   'B0992111G7',
#   'B0B3MJHH2B',
#   'B09ST6ZZQY',
#   'B09XK6WKTB',
#   'B0991Z93GL',
#   'B0992111G7',
#   'B0991XQTMP',
#   'B099224WQ9',
#   'B0991Z93GL',
#   'B0991Z6D25',
#   'B09VX5HWHV'],
#  ['B08ZNFNM99', 'B0B1BPYPFG', 'B002ZCZ0F6'],
#  ['B084RDV6KH',
#   'B084RRMJZ6',
#   'B084RRMJZ6',
#   'B078M2TLC9',
#   'B078LW35V3',
#   'B0BGMSHS6B'],
#  ['B088NDT9CH', 'B08X7811QD', 'B09SHDVFT3'],
#  ['B07V5LWSN5', 'B08T5T6VF3'],
#  ['B07X1SM6T1',
#   'B00ICOTXJA',
#   'B00ICOTXJA',
#   'B07X1SM6T1',
#   'B07X1SM6T1',
#   'B00IE7MO7S',
#   'B095YHGNG2'],
#  ['B00M78G2VO', 'B07JNC1GJ7', 'B0725GDDQX', 'B0827B5582', 'B07WSPM4Z7'],
#  ['0749583045',
#   '1398518166',
#   'B0B5YBZP5J',
#   'B09W29BJMH',
#   'B09TCXLT1R',
#   'B0B7P2Y2DW',
#   'B0B7P2Y2DW',
#   'B0BBGDH766',
#   'B09NYN6Y6S'],
#  ['B0BB2SC94S', 'B0BFQ1TKGG', 'B0B7MPHF36', 'B0BFQ1TKGG', 'B0B8NG1NQ6'],
#  ['B08VDV2JFQ',
#   'B082MQFRNG',
#   'B0949KMLW6',
#   'B089W8P7SW',
#   'B08KQ8XF4G',
#   'B08KQ8XF4G',
#   'B084W3PPMB',
#   'B079DDJ5ZW',
#   'B07Q4BCHZK',
#   'B0100QWEMU',
#   'B00VVS9O6G',
#   'B0B5F5JGXZ',
#   'B084GJZL76',
#   'B0170GOCVO'],
#  ['B004WCKSFE', 'B0041WD050', 'B08VDP5VT5'],
#  ['B0765YGH92', 'B0765YGH92'],
#  ['B08126Q6GX', 'B0992K2B4Z', 'B08DNDW26G', 'B08K8YZKH9'],
#  ['B003XJEEVQ', 'B001RYSHTY', 'B0BJK6QSBW'],
#  ['B08CK6KQDF', 'B092MC9H27'],
#  ['B00U1D9MQO', 'B08DCQGBTH', 'B0728GS2VH', 'B00U1D9MQO', 'B00QV1F1C4'],
#  ['B09TW5JKJQ', 'B08112Q672', 'B01C2DXKJU', 'B08C573XCD', 'B07QNYY67Y'],
#  ['B094GF61Z7',
#   'B09GFWQWSC',
#   'B094GF61Z7',
#   'B094GF4Y7W',
#   'B094GF4Y7W',
#   'B09VLH5LV6',
#   'B09VPYC7CR'],
#  ['B07CBTKZ5R', 'B008LTTGH0'],
#  ['1471154629', '1471154629'],
#  ['B0BBVXD5NH', 'B0BHZVNW3K'],
#  ['B09ZQN9KS7', 'B09ZQNFCL1'],
#  ['B01LCNXF64', 'B07YBG59XJ'],
#  ['B08F5GBD9X', 'B07442P34Y', 'B00RXIIW7K', 'B003VQZC3U'],
#  ['B00VMUSFMW', 'B08TKH1TTV', 'B0B1ZG3GRG', 'B0B9Y1DKGL'],
#  ['B09BG9FTXP', 'B07WDF13WC'],
#  ['0241254027', '0241254027', '0723292086', '0723292086'],
#  ['B0B881NX12', 'B08FMG3NMV', 'B000H2PN08', 'B0013G35KW'],
#  ['B08HT46TVP', 'B08HT46TVP'],
#  ['B09FZFKMVV', 'B08XLVLNSB'],
#  ['B0B28RQRHJ', 'B08XVV6XBV'],
#  ['B00LTOQBYU', 'B084WZ47MP', 'B08NDD7YCB', 'B07S19ZXRC'],
#  ['B07KWYGTC6', 'B07KX2N355', 'B00O869QUC', 'B07KX2N355'],
#  ['B07BTR5353', 'B07917WXR9', 'B0B6HFH3D4'],
#  ['B08YNRJP33', 'B071FK2DQH', 'B085Y4Z2HL', 'B08GRZ9474', 'B08HLKPJ8J'],
#  ['B00BM3TV22', 'B00BM3TV22', 'B004ALKLR2', 'B09JLLQZZF', 'B07D84Z1ZT'],
#  ['B095BYJBJ9', 'B09XK4Z31W'],
#  ['B06XGLGB92', 'B000T211B6', 'B07F68N9ZD', 'B07YX43BSR', 'B00F12YEA4'],
#  ['B09D3SV3T8', 'B07BLDG76K'],
#  ['B0032E6TDI', 'B000OVXYA8', 'B0047X6WUI', 'B0046U4RBS'],
#  ['B0B12C7TLD', 'B091C4L2GQ'],
#  ['B09BNXB16W',
#   'B09JSJYVHM',
#   'B07F2DCMYZ',
#   'B09BNXB16W',
#   'B07F2DCMYZ',
#   'B07F2DCMYZ'],
#  ['B09B343957', 'B0BCKJXHTR', 'B09FRW767K', 'B01MFI2MEF', 'B0859LX8NT'],
#  ['B07F3B2QGW', 'B07Z6YMTLZ', 'B007KIPMIU', 'B07GH2XJWL'],
#  ['B09VPY8KJP', 'B07PZR3PVB'],
#  ['B09PRT355R', 'B09PRT355R', 'B0074GOJ1E', 'B00BYT1KN2'],
#  ['B07K4C6D1V', 'B081CTZ8CZ', 'B083T4Z2WQ'],
#  ['B07WR8G44B', 'B07WR8G44B', 'B08SWBDG29', 'B08H2B35WF'],
#  ['B08L5RKGVX', 'B09QSQQ2ZF'],
#  ['B01E6XA9FM',
#   'B00Q4TL1CC',
#   'B06XFTN1J2',
#   'B01E6X9VG0',
#   'B01E6XA9FM',
#   'B075JGQ4Y8'],
#  ['B099NDZQPX',
#   'B07K9CC9ZL',
#   'B08FR2LJFM',
#   'B08R7KL5QS',
#   'B09NBSWWV6',
#   'B09NBNG4B6',
#   'B09NBNDDC2'],
#  ['B08DKMT261', 'B08DK2X5J8'],
#  ['B09D7D6PJJ', 'B09D767CP9', 'B09D7D6PJJ', 'B0B1LVC5VZ'],
#  ['B0BD5QRTSD',
#   'B0BD5QRTSD',
#   'B098TQR3CY',
#   'B08KQGM9WS',
#   'B09HR3Z1FK',
#   'B09G35RWXL'],
#  ['B0B6BYQ3ST',
#   'B07DPHBFYM',
#   'B07121WVTH',
#   'B07XVSY46L',
#   'B0B6BZMLHP',
#   'B0B39MD1HN',
#   'B0B6BYQ3ST',
#   'B07DPHBFYM',
#   'B07121WVTH',
#   'B09VLKNP75',
#   'B09SQCC8KT'],
#  ['B07GV2Q53S', 'B07F8HZVFS', 'B09QT5HN6K'],
#  ['B000JL69XC', 'B000JL69XC'],
#  ['B08XQ3QJJQ', 'B08ZYCVN88', 'B08ZWVKSH4', 'B00483BKQI'],
#  ['B09JC4BPTQ',
#   'B09JC1YJC7',
#   'B09JC3PVRV',
#   'B09JC4BPTQ',
#   'B07XJLDDDC',
#   'B0BGQHG6VM',
#   'B0BFDYKPL7'],
#  ['B0BJKBD5B1',
#   'B0B7RQC9N4',
#   'B083DNWY8P',
#   'B083DNWY8P',
#   'B083DNWY8P',
#   'B08QS5XR31'],
#  ['B096HP7BMX',
#   'B09ZK15JC5',
#   'B0B8HKH2CK',
#   'B009DIQTJQ',
#   'B09FXKWQG9',
#   'B079K97P1V',
#   'B06XZ1TNYN',
#   'B079K97P1V',
#   'B079K97P1V',
#   'B06XZ1TNYN',
#   'B079K97P1V',
#   'B002OMBM18'],
#  ['B0B1PBBGNB', 'B0B1P6NLCY', 'B0B1PL8TLT', 'B0B23LW7NV'],
#  ['B08HL33CVF', 'B01N4B6VY4'],
#  ['B09WRR5CQX', 'B07HFXHGJZ'],
#  ['B00N99FA5O', 'B00N99FA5O', 'B06W57X25S'],
#  ['B08BCRYWHG', 'B08BCRYWHG', 'B0B7NG3D8Q', 'B0B7NG3D8Q'],
#  ['B09ZL4D4H5', 'B09N8ZKQ88'],
#  ['B07VXV7DZK', 'B07VWVPGH9', 'B07VXV7DZK', 'B07VSSDQJC'],
#  ['B0785NCGCT', 'B000MLYP1C'],
#  ['B0752D33PJ',
#   'B08XKB7PRP',
#   'B0898BXDQR',
#   'B08989D7RZ',
#   'B0BB6RP5CF',
#   'B07RY75V7Q'],
#  ['B08LL945S3',
#   'B08NXD1X1D',
#   'B08NXD1X1D',
#   'B08LL945S3',
#   'B08NXD1X1D',
#   'B08LL945S3'],
#  ['B017WIFFQ6',
#   'B071FJ6FBW',
#   'B07JM6KB5J',
#   'B00K77U60U',
#   'B00AE4W1DG',
#   'B00866AM2G'],
#  ['B09L5S98XB', 'B0BFWNW84L'],
#  ['B09HN23KBT',
#   'B0B46L6PJP',
#   'B0B453NY6J',
#   'B0B46L6PJP',
#   'B0B453NY6J',
#   'B0B46L6PJP',
#   'B0B453NY6J',
#   'B08G57M582',
#   'B09F65P34Y',
#   'B07G1YMVT8',
#   'B09F65P34Y',
#   'B094QHJNBH'],
#  ['B07W7KFLBN', 'B00CL6353A'],
#  ['B0BF5T93PQ', 'B06XFTGPWG'],
#  ['B08RJYKSK5', 'B08RJYKSK5'],
#  ['B0851HKN78', 'B0B2DK1XTQ'],
#  ['B07R2F1H65',
#   'B07R2F1H65',
#   'B07R4WYRQN',
#   'B07R4WYRQN',
#   'B083JKKZXW',
#   'B07R3FRPSG',
#   'B07R3FRPSG',
#   'B07R3WC6TG'],
#  ['B0BH3X8J18', 'B07NDZ9JTL', 'B08MM7QDB6'],
#  ['B08LHHGYFW', 'B00E9T48NI', 'B08LHHGYFW'],
#  ['B07F3B2QGW', 'B003ZG7CMA', 'B002ISD8M4'],
#  ['B0BGFV1XQ1', 'B09P7QCFDH', 'B09CD35XB8'],
#  ['B08DD8STJ9', 'B08DD8896N', 'B08CCKF42Z', 'B073ZKD8WT', 'B01MRIJ0BO'],
#  ['B089Y246KV', 'B08FHJ6Q1B', 'B089YFFY98'],
#  ['B0958V6N3D', 'B09HF3T8MN'],
#  ['B00OHQ9NAQ', 'B07QGSBV38'],
#  ['B0B7W9LVCS', 'B0B8T2TKX1', 'B0B7XM9RZY', 'B0B63PHYW9'],
#  ['B0B5F62YDF', 'B001NYGB8W', 'B07N1FZR48'],
#  ['B09X2HVCP3',
#   'B075CM7JSB',
#   'B01LXWLZNG',
#   'B09ZYC18G3',
#   'B07T1Q96MF',
#   'B081CQMYQS',
#   'B07B9VVB45',
#   'B07RYXR7T6',
#   'B01LZJ4TRG',
#   'B01L27HBZ6',
#   'B09XMSH6ZC'],
#  ['B07WHHJGKJ', 'B07MNXRKJ9', 'B08RF11BJ5'],
#  ['B0B8FWRYB4', 'B09XQDD9VS'],
#  ['B09PRTVMJX',
#   'B001A34BE2',
#   'B09XVGDKBM',
#   'B0BBPRPDRH',
#   'B0BCHJDSP2',
#   'B0855S9FKG',
#   'B01DKBR9G8',
#   'B08K4HNG6B',
#   'B00AIFAYLM'],
#  ['B095NX9YJ2',
#   'B09SFSP54Q',
#   'B0B4G3B9MR',
#   'B09FHJ5M4M',
#   'B08JZ8VWQS',
#   'B08NBGQKR3',
#   'B0B49QYVY8',
#   'B0B49P28K3',
#   'B08JZ8VWQS',
#   'B0B4G3B9MR',
#   'B09FHJ5M4M',
#   'B08NBGQKR3',
#   'B0B49QYVY8',
#   'B0B49P28K3',
#   'B09PYC7FDB',
#   'B09PY5P23C',
#   'B09PYGH45S',
#   'B09YTZBR6Z',
#   'B0B4G3B9MR',
#   'B09FHJ5M4M',
#   'B08NBGQKR3',
#   'B0B49QYVY8',
#   'B07DJ4ZKYX',
#   'B07HH94Q4N',
#   'B0BHNLMK9J',
#   'B08F58KT79'],
#  ['B09VPHVT2Z', 'B099DP3617'],
#  ['B07PPHN21G', 'B07PPHN21G', 'B07PPHN21G'],
#  ['B07Z3GG2KG', 'B082X6WZ5F', 'B07FSFPG58'],
#  ['B09V7RN5QG', 'B09V7PZ8PF'],
#  ['B0757MQXQH', 'B00NFYJYJG', 'B08Q4LVHF2', 'B0757MQXQH'],
#  ['B086DWVZQJ', 'B07WS941GY'],
#  ['B0B9SZ8NGQ', 'B001RIYICK', 'B092N2MXQT'],
#  ['B079VP5LFQ', 'B09TPVP9KY', 'B079VP5LFQ'],
#  ['B01COL8S1A', 'B071W9823H', 'B09STMRLBN'],
#  ['B07C9V1MGG', 'B077NQ1XC5', 'B0918LB9VR'],
#  ['B007IEGR9Y',
#   'B0B2WGKFH8',
#   'B0B2WGKFH8',
#   'B0B9264QRH',
#   'B0B9264QRH',
#   'B0B78FZZJ4',
#   'B08JTGQV8F',
#   'B01COL8UUY',
#   'B01COL8UUY'],
#  ['B07J4WX98D', 'B0095U75ZY', 'B0095U75ZY'],
#  ['B07YVXR5ML', 'B07YVXGFLS', 'B09DPY5GHD', '1408856778', '1407163280'],
#  ['B071FJ6FBW', 'B019XXLZX0'],
#  ['B09WLP4PBB', 'B0BD7S593P'],
#  ['B07KMTQTCB', 'B09FYHNGSD'],
#  ['B0B5FGQ5VB', 'B0B5FB17RB'],
#  ['B0017TQ3QI', 'B0017TQ3QI'],
#  ['B0B1JMRDWK', 'B07VM1HQDJ', 'B08CDJGJH5'],
#  ['B08LH1ZVX1', 'B08LH1ZVX1', 'B001MGAUTW'],
#  ['B09SGN9GMX', 'B092MM187D'],
#  ['B09H376NVC', 'B0046MLZLG', 'B09H376NVC'],
#  ['B07V6LVQT9', 'B01L9A709S', 'B07V5KJTVB'],
#  ['B091TXXWXS',
#   'B0733CKYSS',
#   'B08HS8QJML',
#   'B0733CKYSS',
#   'B07VBSN5XB',
#   'B08DKF1S7J',
#   'B08DKLZQF7',
#   'B08DKF1S7J',
#   'B08DKLZQF7',
#   'B08DKLZQF7'],
#  ['B000LU8XGC', 'B08PF9RW4Z', 'B01DBRAUU8'],
#  ['B08Z8447ZN', 'B091DML4SL'],
#  ['B01B23ZK94', 'B00299JIQ2', 'B081DDS4HK'],
#  ['B09TBHJ2MN', 'B0B65VBSDG'],
#  ['B0041MOOXW', 'B0041MOOXW'],
#  ['B09BTKNGN5', 'B096HKQK9W'],
#  ['B00QWRTCPY', 'B00QWRTCPY'],
#  ['B07WJJ5SJ4', 'B073TX6WSW'],
#  ['B07Z9M2QCD',
#   'B0BFPBP59H',
#   'B07G2M426Y',
#   'B09PN28WT4',
#   'B001691BMA',
#   'B00005RF5G',
#   'B00O0YKYP8'],
#  ['B01L2K1R76', 'B085HC77MV', 'B01L2K1R76'],
#  ['B0BC9V9BBH', 'B0BCW9YJLH', 'B07B3LY3FX'],
#  ['B01N1FV55I', 'B0B6C8QHBP'],
#  ['B07Y4V7QCP', 'B07XJMF82G', 'B086V8QLB7', 'B07THZ4CXQ'],
#  ['B01F8HSMEK', 'B0168BIKBU', 'B01F8HSMEK', 'B0168BIKBU'],
#  ['B09H2T8Z92', 'B09H2TGF3G'],
#  ['B00T3EPNTC', 'B074SVDL1J', 'B07VMLPRS4'],
#  ['B09315ZKWT', 'B09316DC61'],
#  ['B06XSH99SQ', 'B06XSJ7FYZ', 'B06XS1439K'],
#  ['B08ZJNWZCP', 'B08XJWZZCG'],
#  ['B07FWYNHV6', 'B07SL5FG6G'],
#  ['B09QCTW4Z1', 'B09ZPHT2S6'],
#  ['B07Q1HYKKK', 'B07Q2CMVY5', 'B07NRN6RXY', 'B07Q1HYFMV', 'B07Q1HXJPC'],
#  ['B0B3RXFGND', 'B097S33TL9', 'B00BWU7MNU', 'B00BWU7NZC'],
#  ['B0BCW2KBWV', 'B0BGN5GTG4'],
#  ['B01ENCGDRE', 'B01ENCGDRE'],
#  ['1338210203',
#   'B07W5QM4DP',
#   'B08FPCLH24',
#   'B07W7FLKRW',
#   'B07W5QM4DP',
#   'B092QHL1ST'],
#  ['B081W9QTH9', 'B09MR4B6DT'],
#  ['B0179QUK8Y',
#   'B0176V7V3E',
#   'B09292LGWF',
#   'B003AIF4Q4',
#   'B07MSGMZBL',
#   'B07M6HQ9G8',
#   'B07B8QDSNQ',
#   'B07B8K7MFW',
#   'B08L8G9S5W',
#   'B08L8GLPDG',
#   'B07M6HQ9G8',
#   'B08L8GF69F',
#   'B08L8H7LYS',
#   'B07M6HQ9G8'],
#  ['B0B3MF5VHR', 'B0756ZWNS3'],
#  ['B09NPKQ69H', 'B09QSMN9TG', 'B09NPKQ69H', 'B09QSMN9TG', 'B09NPKQ69H'],
#  ['B07VPPNK2Z', 'B07VPPNK2Z'],
#  ['B0BC476W3L', 'B07Q82BG9G', 'B07PY72WMF'],
#  ['B0932R6RCB', 'B0B3MNHN4M'],
#  ['B07L5MTD5Y',
#   'B07BPQY7W1',
#   'B093QB4PSF',
#   'B07RCBJ6FG',
#   'B07RCBJ6FG',
#   'B08C62HMMZ',
#   'B08C62HMMZ'],
#  ['B0B6DS8RGQ',
#   'B0B6DWZJCZ',
#   'B0B6DS8RGQ',
#   'B09W5MFYR8',
#   'B09W5MFYR8',
#   'B0B6DWZJCZ',
#   'B0B6FFP5MJ',
#   'B0B6FFP5MJ'],
#  ['B09F6MJJF2', 'B07JK4MXFX'],
#  ['B07G4CWRDQ', 'B07Q5PQZ2B'],
#  ['B09NQJ7Q28', 'B09NQGVYWW'],
#  ['B09WMYRFT8', 'B08K3GG49Q', 'B08K3G5TR1', 'B09WN31XWD'],
#  ['0141976144', '1529148774', 'B099RWTQQZ'],
#  ['B09X5ZFY29', 'B0BF9PSNWL', 'B08H5NPHLT'],
#  ['B08GLPMPYD', 'B08GLNZ9KG', 'B0B5CM9GPP', 'B0B5CWSB5P'],
# ...
#   'B08X1G2D11'],
#  ['B0881PGTPX', 'B09MJXQHP6'],
#  ['B01EDKGFGU', 'B0B81KX8XK', 'B091F65ZYX', 'B07K73K2F5'],
#  ['B0BFJH79T8', 'B0B94CNT54'],
#  ['B096XSVSVB', 'B07P23T4K7', 'B07NYWJSDH', 'B07P12PQSY', 'B07XHLS8R2'],
#  ['B08KJKSLG4',
#   'B07XHS5TMG',
#   'B0182QCU7E',
#   'B00EEAL0R4',
#   'B002OE2V1G',
#   'B002OE2V1G',
#   'B0182QCU7E',
#   'B0BCLGK9DD'],
#  ['B07KM28NZY', 'B0B8NSV7GS'],
#  ['B07WVP7QWM',
#   'B07VVFWT1M',
#   'B097BZY9TT',
#   'B098DW8D59',
#   'B07WRG21LX',
#   'B087QHF347',
#   'B09STPDBWC',
#   'B07VSFS2J4',
#   'B06X6J4W2Y'],
#  ['B07PRSFBFB', 'B07CNWCXYP'],
#  ['B08DK58TPS', 'B08DK58TPS', 'B000KGCO30', 'B011YDCK0Y', 'B08DKLG2F8'],
#  ['B0B2P3GQRH',
#   'B0B2P1KJ67',
#   'B091V5L86H',
#   'B0937HCBWT',
#   'B084RJ5JWG',
#   'B011UAPFLC'],
#  ['B0BDFGKC1W', 'B07KCF3GLN'],
#  ['B098SZWBM6', 'B074JHRC6J', 'B074JHRC6J'],
#  ['B07R4KBDXR', 'B07ZNCXY26', 'B018DF82EE'],
#  ['B09J4T5KFN', 'B0B9JTMQHM'],
#  ['B07XD9HCR8', 'B08CKFKVP1', 'B0BBM3218Z'],
#  ['B07RJ2K4ZC', 'B09DSBZY95', 'B09DS4H277', 'B07RJ2K4ZC', 'B07RJ2K4ZC'],
#  ['B002K5SWA8', 'B002K5SWA8', 'B002K5SWA8', 'B01N7TLGIG', 'B0045X6EX0'],
#  ['B08L6P5BSC', 'B08D9NCS55', 'B08D9NCS55'],
#  ['1509894225', '1529034396'],
#  ['B08MXS8NY3', 'B09WB48V7S'],
#  ['B09DP1ZPGL',
#   'B09L81GKZZ',
#   'B07BML6H35',
#   'B09L81GKZZ',
#   'B09DP1ZPGL',
#   'B07BML6H35',
#   'B07Z5LBQFJ',
#   'B07XD44R34',
#   'B0BBLYY4KS',
#   'B08L3Y1J7K',
#   'B09DCL5VC7'],
#  ['B09TZT4DXY', 'B0943T74QG', 'B094ZBGCJG'],
#  ['B081QXPV1Y', 'B097F8H1MC', 'B081QXPV1Y'],
#  ['B009YEFHN8', 'B006UJ394E'],
#  ['B08TZTH3LC', 'B08XZDWJSM', 'B08TZTH3LC'],
#  ['B09XV92MXD',
#   'B09XV88CB3',
#   'B09XV6TDSY',
#   'B09XV92MXD',
#   'B09XV92MXD',
#   'B09XV88CB3',
#   'B07MB98MN8'],
#  ['B098PKR65Y',
#   'B0B9XVYTB7',
#   'B00S58M62O',
#   'B0989PKD4B',
#   'B0785DRYG8',
#   'B008MVF5WW'],
#  ['B010DQE40W', 'B01JPONHCY'],
#  ['B016B32ODU', 'B08DLSKW53', 'B07FMC7791'],
#  ['B09XCKJCDK', 'B09GV8TDBK'],
#  ['B08SY8W216', 'B07X63K6KZ', 'B07T6HW49X'],
#  ['B08Y8L75S1', 'B08V5K7W31'],
#  ['B092MTKJNC', 'B0BFB9TXPS', 'B0BFB9YT37', 'B072HYJBHX', 'B071LC5G1H'],
#  ['B09FCD8HKV', 'B0B6YSCLS3'],
#  ['B005CC5TU2', 'B09RQZ5VC1', 'B09WN4CWD3', 'B000KHTEZ0'],
#  ['B0B5DQC7BZ', 'B0B5DRCSZS', 'B0B5DTLS8W'],
#  ['B09LQYT11P', 'B001NPFM4U', 'B08L85C4YP', 'B0191BQXK4'],
#  ['B00O9RYS7Q', 'B00O9RYS7Q'],
#  ['B00IK5X0HW', 'B00FFMG4VM', 'B00IK5X0HW'],
#  ['B08K34T1DF',
#   'B08K39KDHB',
#   'B09W5MFYR8',
#   'B08X6S21WF',
#   'B09PYSX2CN',
#   'B08X6S21WF',
#   'B09PYSX2CN',
#   'B08HH76VSS',
#   'B08HCSLLC3',
#   'B09W6BMWM4',
#   'B08VNJ4FZ8'],
#  ['B091V2GXR4', 'B09QT57CWM'],
#  ['B08HWD6M6Q', 'B01LQ6EWQ4'],
#  ['B08ML1T8H9', 'B089XZ12BR', 'B08CGK65DX', 'B089XZ12BR'],
#  ['B0B5HFP4Y1', 'B08T1B1FH5', 'B08PD2FV1F'],
#  ['B07QPBZNC6', 'B089CKRDZS', 'B07MP1T5SG', 'B075NHZKDP'],
#  ['B082MRDYVM', 'B096VBQ67C', 'B00J41BK1O', 'B00J41BK1O'],
#  ['B0118K7K4O', 'B00552K0GM', 'B07H4JBRV1'],
#  ['B08F25Y7X5', 'B09NRG2YT3', 'B07SK231QQ'],
#  ['B09N8M646K',
#   'B09N8Y7RSM',
#   'B09HSV5FPB',
#   'B09TDYN7BB',
#   'B09N7Q1WJ2',
#   'B09N8Y7RSM',
#   'B09N8M646K',
#   'B09MT25G3N',
#   'B09TDYN7BB',
#   'B09NB6MBCG',
#   'B09NSQ48KY',
#   'B09NSQ2M83',
#   'B09JFSJVTQ',
#   'B09T8DJ4RS',
#   'B09TDYN7BB',
#   'B09NXQ161L',
#   'B09NX7TF98'],
#  ['B08JPWM5QL', 'B005VC6RPO'],
#  ['B00NJTAZEU', 'B00NJTB3VY', 'B00NJTB2YM', 'B09SH9MRX3'],
#  ['B00LU9H1DO',
#   'B00LFHN6YY',
#   'B01N9HU7BE',
#   'B00YUAGMYE',
#   'B00LU9H1DO',
#   'B00LFHN6YY',
#   'B017MG4SZ2',
#   'B01N9HU7BE',
#   'B09YPWRSCG',
#   'B017MG4SZ2',
#   'B01N9HU7BE',
#   'B01N9HU7BE',
#   'B00YUAGMYE',
#   'B01N9HU7BE'],
#  ['B00XUARRLW', 'B07Z7FQCJ9', 'B07N391ZTV'],
#  ['B08BLJWYJ4', 'B08ZDTX9MJ', 'B08ZDW8P4L', 'B09MJNNM6Y'],
#  ['B0714D3LL3',
#   'B002ECY206',
#   'B07B7TYHRN',
#   'B07B7XVVMS',
#   'B002ED46WO',
#   'B0039ZLDL8',
#   'B078VN32Q5',
#   'B002ECY206',
#   'B0714D3LL3'],
#  ['B01MPY1IQY', 'B0B4DW2H6Y', 'B0B4DW2H6Y'],
#  ['B01LWM3NHT',
#   'B01MF4C1ZX',
#   'B01MYX1R6M',
#   'B01LWM3NHT',
#   'B01MF4C1ZX',
#   'B01LWM3NHT',
#   'B01MF4C1ZX',
#   'B01MECPCMT'],
#  ['B010PM76ZY', 'B010PM76VS', 'B010PM6XO4', 'B071HJ26S8'],
#  ['B0BFRFL6KP', 'B0BFRCYM72', 'B0B6QNTQMM', 'B0B8V4NR5K', 'B0B12PYTWP'],
#  ['B09YL1R3D3',
#   'B0B5L2SN16',
#   'B095SL9KP3',
#   'B08L6QW263',
#   'B095SL9KP3',
#   'B08L6QW263'],
#  ['B0848FWP4M', 'B0848FWP4M'],
#  ['B0B5DH71KT',
#   'B0B5DGGTZ8',
#   'B0B5DGK1F7',
#   'B096MXCBMV',
#   'B097PXDR13',
#   'B097PVHDX3',
#   'B097PXDR13',
#   'B097PWPB4Z',
#   'B097PWVDJZ',
#   'B097PWK3BQ',
#   'B097PTM3SH',
#   'B097PYKN7G',
#   'B097PW83MN',
#   'B07RZ9269M',
#   'B07S1CK5JL',
#   'B07S1BQZRY',
#   'B07S1CK5JL'],
#  ['B09X31ZNPN', 'B09R9BW6XP'],
#  ['B098S3RWNN',
#   'B089Y7D4VP',
#   'B008HRL33G',
#   'B09LYDBXST',
#   'B099KNJXLK',
#   'B096RV8F2G'],
#  ['B0914XRHD3', 'B08L76Z4G5'],
#  ['B095K6T24V', 'B07KJTCRBS', 'B07XHXLXZD'],
#  ['B0B3WQRK77', 'B0B3WPSH2T'],
#  ['B07R6W9NPT', 'B0BG9NFXQG'],
#  ['B08MB3P3WN', 'B09V53BTLW', 'B07HH2L1PG'],
#  ['B09Q226L6L', 'B07RMX9V5Y'],
#  ['B07WZY44MC', 'B08JYK7JP8', 'B08532BSF7', 'B08CDJNX7Q'],
#  ['B000SDQ224', 'B08C36SCGK'],
#  ['B07QGQXS31', 'B0B5DF9FVH', 'B092WBHJGG'],
#  ['B079G4DGP6', '0241439469', '1409537072'],
#  ['B07YG25GG2',
#   'B09ZTXVNVD',
#   'B09DKX4H65',
#   'B0BB76VCFV',
#   'B09XGR1X8Y',
#   'B09DKX4H65',
#   'B09271X6V7',
#   'B09FSYXP5T',
#   'B09NXNSDX4',
#   'B08HGYMKB2',
#   'B08LGZ3336',
#   'B086QGSCJ7',
#   'B016NY7784',
#   'B086QGSCJ7'],
#  ['B08HL4CWT8', 'B00SWUGFH2', 'B00SWUGGVM'],
#  ['B07ZV3QFR5',
#   'B07P8L2946',
#   'B07P8L2946',
#   'B079211F5P',
#   'B07J58WB4Z',
#   'B07HZFQHXZ',
#   'B07HZFQHXZ',
#   'B07J58WB4Z',
#   'B07HZFQHXZ'],
#  ['B075Z2DTTQ', 'B01H2T4HV4'],
#  ['B09PDYQ4N7',
#   'B09PFNDMJ8',
#   'B0B67VFCXT',
#   'B09PDY824V',
#   'B09PDXW2QH',
#   'B09PFPCP32',
#   'B0B67VFCXT'],
#  ['B0BD3BGV3V', 'B0BHHNM2H8'],
#  ['B09J829SCN', 'B09J8KLM6J', 'B09HGVNH9C', 'B091XRJ5SN', 'B09J8KLM6J'],
#  ['B014SZAVBU', 'B00FGOM9DQ', 'B00FGOM9DQ'],
#  ['B0B5KT77CH', 'B06XHC62JJ', 'B075V4CLW2', 'B06XHC62JJ', 'B09QXB454P'],
#  ['B098F363MH', 'B098BHY4X2'],
#  ['B0B9S4HY7V', 'B09NQC9MZW', 'B09QMFLZ6T', 'B0B9S4HY7V', 'B09NQC9MZW'],
#  ['B09FLD6XK9', 'B0B5TRM37Z', 'B07ZS95G7K', 'B07ZS8QJPB'],
#  ['B0B9RFK5S2', 'B08LPMVWVF', 'B08MFF725V', 'B07XC7HZ8P'],
#  ['B087FBFJ1Z',
#   'B09245TK13',
#   'B08TC7294M',
#   'B09VFGZXLW',
#   'B09NMC9DJ8',
#   'B08GG9SY78',
#   'B07F28HT4C',
#   'B09VFGZXLW',
#   'B09NMC9DJ8',
#   'B08XM4HPWV',
#   'B07L8X67TG',
#   'B08FL9BHXR'],
#  ['B084MM1HDC', 'B084MM1HDC', 'B002BB0D9E', 'B08SWRZWTX'],
#  ['B07QS4QLCT', 'B07QPV9Z7X'],
#  ['B09YVBX5RB',
#   'B08JXKYC6V',
#   'B08JYBZF9L',
#   'B08XYJM6XS',
#   'B082VLY8WT',
#   'B01MU5YPGI',
#   'B08XYJM6XS',
#   'B08XYKRXW2',
#   'B09YVBX5RB',
#   'B09YVF6M97'],
#  ['B09FPWCR3H', 'B00CG7FC4E', 'B00CG7FC4E'],
#  ['B01AS7QYO0', 'B07GSW9X37'],
#  ['B08KJGNG8D', 'B09L4ZRBL7', 'B09792NV5F'],
#  ['B09B3K85LH', 'B08GMMVHFC'],
#  ['B09RK9WTVY', 'B08YKGSTNN'],
#  ['B0933LBC8W', 'B07M7VX2NB', 'B0933LBC8W', 'B07M7VX2NB'],
#  ['B0058V5Z1K', 'B01MR9JA8Q', 'B07G5JZSFG'],
#  ['B09MKDCR87', 'B09P1F9DYM', 'B09H49PKYD', 'B09SZ27BM1', 'B098CYLLZK'],
#  ['B07V46T8H4', 'B004IEJF6E'],
#  ['B0B8J6SNHX',
#   'B09WKHN2B8',
#   'B09WKHT25Z',
#   'B01CUF8W2A',
#   'B01CUF8TSC',
#   'B00CMR3H0O'],
#  ['B091SV5Y8T', 'B07WKCHH7D', 'B09W9QXTN2'],
#  ['B000GY75RQ', 'B009DGO0Q2'],
#  ['B07TTMJHZM',
#   'B0B24TG86Q',
#   'B088D2GVTR',
#   'B0B21FT92X',
#   'B088D2GVTR',
#   'B09ZT1Y5MZ',
#   'B09ZSMV9LM',
#   'B09ZTBFHMF',
#   'B09Y4BDZHB'],
#  ['B01E7MV4ZQ', 'B00SYLH424'],
#  ['B089CR7RQ7', 'B09M64N25H'],
#  ['B09C13Y69W',
#   'B0B5TMMK6S',
#   'B09CV6W42V',
#   'B0B8WZK311',
#   'B0B4N68VKX',
#   'B09C1KVT2M'],
#  ['B07T42KRCB', 'B0041OQMYE'],
#  ['B0BGH717YT', 'B09G2QH53B', 'B082ZZ6233', 'B085WPKF4K'],
#  ['B01DZYO25G', 'B00TFB0YTM', 'B072L235Z5'],
#  ['B003XR9G02', 'B003XR5FD4', 'B003XR7FNW', 'B003XR7FIW'],
#  ['B07VSVYK3Y',
#   'B0BJVGQMKM',
#   'B0BJVGQMKM',
#   'B0BJYYKF8D',
#   'B0BJVGQMKM',
#   'B0BJVGQMKM',
#   'B08ZCWJX7H',
#   'B085ZMLVTY',
#   'B085ZMLVTY',
#   'B09X9VPNDL'],
#  ['B088F27XMC', 'B014WLL3UI'],
#  ['B08FMSCCG9', 'B098LKMGQZ'],
#  ['B08HD4131D', 'B07TZ2ZT6L'],
#  ['B097973J2L',
#   'B000WCB4RO',
#   'B079K56H8T',
#   'B00I506718',
#   'B079K56H8T',
#   'B079K56H8T',
#   'B07VPP2SDK'],
#  ['B006LMFJS4', 'B0001GRVOG'],
#  ['B08CRRR48N', 'B074SV28VH'],
#  ['B08NSK4FD1', 'B09X78TFHQ'],
#  ['B000TAQOMO', 'B07T2V2J95'],
#  ['B013RYN5ZC',
#   'B073WV3CJ2',
#   'B0847MP8TB',
#   'B07N9CDGWW',
#   'B013RXT9NU',
#   '1788707559',
#   '1788707559'],
#  ['B074184RW8',
#   'B07RL6LW22',
#   'B096HHTMXD',
#   'B091K8YDBB',
#   'B07L4JKGHL',
#   'B08H133S2L',
#   'B0076XNIAI'],
#  ['B075SY3BN1',
#   'B09D52S43V',
#   'B09D52S43V',
#   'B082DMWKH5',
#   'B007U59CMK',
#   'B07KWRXXNQ'],
#  ['B07DMPZCL5', 'B0001IX3MI'],
#  ['B0821VNVPG', 'B08232THT6', 'B0B393TBGR'],
#  ['B08NF6XPRT', 'B08VRPCDDK'],
#  ['B08NFRHP7S',
#   'B087QCY84L',
#   'B087QBTM6R',
#   'B07BK5P5ST',
#   'B01LQE4ZS6',
#   'B01LQE4ZUE',
#   'B07C3MQYQV',
#   'B08L9C774T'],
#  ['B0B5WBDHGR',
#   'B09835PG2K',
#   'B09836QMJG',
#   'B0B5WBDHGR',
#   'B0BB28SJQQ',
#   'B01KNWYGMW'],
#  ['B0197TYBGI', 'B08RSJ5R9W'],
#  ['B084ZRBBY4', 'B0B2F39VH1'],
#  ['B08KT5RMXV', 'B08KT5RMXV'],
#  ['B00EIC1NZW', 'B005FF1A9K'],
#  ['B00A59MCO8', 'B07TWFZLD6', 'B086G2FKB5'],
#  ['B09HYVGFZM', 'B09YR2LPHD', 'B09HYVGFZM'],
#  ['B07B2T345D', 'B07GJKFRGH', 'B07B2T345D', 'B09GSK34J4', 'B09GSK34J4'],
#  ['B08CFTN1HV', 'B07PFFS3SB', 'B0897SQXKV'],
#  ['B0BCL6NL1C',
#   'B0BCL741LN',
#   'B0BCLY9KPZ',
#   'B0BCL4P7P5',
#   'B0777NNY1X',
#   'B00KU69HRQ',
#   'B00Z0A77DS'],
#  ['B07W7FLKRW',
#   'B07W5QM4DP',
#   'B08FPCLH24',
#   'B08FKQZVWV',
#   'B08FPCLH24',
#   'B08FL61CKL',
#   'B07W5QM4DP',
#   'B07W7FLKRW',
#   'B08FKZWPGH',
#   'B091M9N4FC',
#   'B091MF5C4W',
#   'B07VRF976B'],
#  ['B074M96FKW', 'B07YNDWY61', 'B07V8ST3P7', 'B07YNDWY61', 'B07V8ST3P7'],
#  ['B00F9H1I8C', 'B00F9H1HDI'],
#  ['B09KNQL782', 'B09KNQL782'],
#  ['B09Q2RJ5RC', 'B0B6VPC8DP', 'B0B6VPC8DP', 'B09NRMXMBQ', 'B096ZZJYCL'],
#  ['B08B8WNVHZ', 'B087N4HT6Q', 'B09Q4818DS'],
#  ['B09SZS5M5Q', 'B07KYX5PKQ', 'B07KZ5LFX9'],
#  ['B08GYG6T12', 'B07NW8RPYN', 'B07ZKRM12C'],
#  ['B07FM7DPHY',
#   'B071FJ6FBW',
#   'B07PMJZZSN',
#   'B07BNTSTZK',
#   'B01GFJWG88',
#   'B084H8X4SW',
#   'B01GFJWHZ0',
#   'B07LC9H6BZ',
#   'B07LC9H6BZ',
#   'B06XYG1P2G',
#   'B09M9K3K1F',
#   'B09M9M4SCV',
#   'B0BF2RR7CY',
#   'B0BFPNBV7Z',
#   'B09QKQBGJL'],
#  ['B005LUT0TG', 'B005LUT0TG', 'B0096PIJYO'],
#  ['B098N4F2ZK', 'B07Y34NDKB'],
#  ['B077SNNDTB', 'B08PNRCWMT'],
#  ['B08YN71X1K',
#   'B08FRFQFK8',
#   'B06X1FH17Z',
#   'B08GPVCWSK',
#   'B08GM34FQD',
#   'B08GPVCWSK'],
#  ['B0B46NT69N', 'B0B46NT69N'],
#  ['B001FKZAQI', 'B001FL7AOM', 'B00782C5OM', 'B00AXA4PJ4'],
#  ['B09CZ8KZLZ',
#   'B09SQ135WL',
#   'B09SQ24961',
#   'B09SQ135WL',
#   'B09SQ24961',
#   'B0B88NS8LX',
#   'B07LGVV9C9',
#   'B07LH5R359',
#   'B07LH3F2D8',
#   'B07LH61NLS',
#   'B07LH5QTLV',
#   'B07LH5XY6K',
#   'B07LGWJV4Y',
#   'B07LH4V1WM',
#   'B07LH59TCZ',
#   'B09F9XN5B6',
#   'B09RB8G9RX',
#   'B07Q3GPQ5R',
#   'B09RQZ37MF',
#   'B0B88PY5CC',
#   'B07NVSTPVW',
#   'B07LH56K7F',
#   'B07LH41HMH',
#   'B07LH6N2TM'],
#  ['B0BGQ3GFFS',
#   'B08C36N3S5',
#   'B0B7BH98GT',
#   'B0BGQ2CQTB',
#   'B07Z8BFYT9',
#   'B0BGQ4891B',
#   'B0BGQ3GFFS',
#   'B089S1FGQV',
#   'B0B4P4PKKR',
#   'B0B7BH98GT',
#   'B0BGQ2S2ZN',
#   'B0BGQ2CQTB',
#   'B095KPF8XX',
#   'B07Z8B2WXW',
#   'B0BGQ6XVJD',
#   'B0BGQ3PBML',
#   'B0B7B29XVY',
#   'B08C36N3S5',
#   'B089S1VWGK',
#   'B0BGQ3QSXC',
#   'B0BGQ5P93J',
#   'B0B79Z965N',
#   'B08GM4Y88S',
#   'B08QTTP15Q',
#   'B08N18MNPL',
#   'B08N18T141',
#   'B08KDK6FS1',
#   'B08KDGWFLX',
#   'B0B3HS27VP',
#   'B09CNRZZQG',
#   'B09CNQF7LN',
#   'B0851KN668',
#   'B08KFHDPY9',
#   'B0851KN668',
#   'B08CK1Q29J',
#   'B08CKKK47M',
#   'B08CK1Q29J',
#   'B09YM1NF3W',
#   'B08CKBX7YV',
#   'B08CK1Q29J',
#   'B09YM37Y4P',
#   'B09YM4S7N7',
#   'B09YM3NKTC'],
#  ['B08PKLFM9T', 'B08F2NDB39', 'B07P8K3PHZ'],
#  ['B078J98M7C',
#   'B08L879K86',
#   'B078J98M7C',
#   'B078JLCZFP',
#   'B078J98M7C',
#   'B01A84QLS2',
#   'B0942XQJYX',
#   'B0943DGDNZ',
#   'B09434RPTF',
#   'B0942XQJYX',
#   'B0943DGDNZ',
#   'B0B51PDQ99',
#   'B0942XQJYX',
#   'B0943DGDNZ',
#   'B07H744FZT',
#   'B07H72KK7H',
#   'B07H75RS2G',
#   'B07H74GB7M',
#   'B07H744FZT',
#   'B07H72DM65',
#   'B07H746Y2W',
#   'B07X84HMPX',
#   'B07TYFQTS9',
#   'B07V3NFSG3',
#   'B071X4RKZJ',
#   'B08L879K86',
#   'B0B51PDQ99',
#   'B01N4HABQT',
#   'B019E2VLZW',
#   'B019E3KTLS',
#   'B019E2VLZW',
#   'B0942XQJYX',
#   'B09434RPTF',
#   'B08L879K86',
#   'B08LHG4VNG',
#   'B01A84QLS2',
#   'B0942XQJYX',
#   'B0943DGDNZ'],
#  ['B08QMYX4C5', 'B09GFR718F', 'B08XMV58LC', 'B08XMS7DKR'],
#  ['B08BC68RBV', 'B0859WDK81', 'B007V1RNYC', 'B00K1BG2E6'],
#  ['B08CZQG8RQ', 'B07CTRRKDX', 'B07L4BH5C8', 'B07CTP3KFM'],
#  ['B093LQHR2Y', 'B093LQHR2Y', 'B07J1F1KWS', 'B08JKMKVPT'],
#  ['1838770011', 'B07YX1S553'],
#  ['B005A3FEGW',
#   'B0059SE95A',
#   'B005A3FEGW',
#   'B08XZ94BS5',
#   'B00WZ8WI8C',
#   'B00WZ8WKYO',
#   'B09NRLNVC6',
#   'B09XF43P6D'],
#  ['B09LHWVLJN', 'B08QYYX1PW'],
#  ['B08FDKQW27', 'B0160JCC5U', 'B08FDKQW27', 'B0160JCC5U'],
#  ['B092JVZ2N1', 'B0B14F9638'],
#  ['B072QF54FC', 'B09FSW1158', 'B002WD8HIK'],
#  ['B073XM9JYX', 'B073XM9JYX'],
#  ['B0B9HPZCFK', 'B0B9HPZCFK'],
#  ['B06XY3VPHF', 'B091FZHF29', 'B000GG0TQI'],
#  ['B07THQFQXX', 'B07THSWY7S'],
#  ['B08N5KCCJZ', 'B09C87MKN1', 'B08N5KCCJZ', 'B08N5KCCJZ'],
#  ['B01GO25H6Y',
#   'B08GPNQZ59',
#   'B01GO25H6Y',
#   'B09YD3KHC1',
#   'B08VH2SFTS',
#   'B08D8K25MW'],
#  ['B09Y45X3PF', 'B09F3G8YKC', 'B0BB7P6C8Q', 'B0841NKF84'],
#  ['B01IBO15UA', 'B071HTRJ5K'],
#  ['B01N5JUNEO', 'B0BBSDJN9J'],
#  ['B07R9SB2R6', 'B09MDYZCLK', 'B09DKK5M7N', 'B099ZCNHWC'],
#  ['B014IVJ2GY', 'B0BBFTDS6R', 'B09Y5GMVZT'],
#  ['B0B8RFVDD8', 'B0B8RG4K7W', 'B0B8RG4K7W'],
#  ['B07G9R19T3', 'B07G9RPC2N', 'B07FHPP6QV', 'B07F4LN1HG', 'B0861MVXFX'],
#  ['B097XRXZGL', 'B09PNCLWGH'],
#  ['B09XBRZLQZ', 'B09PVN16HF', 'B0B4T5QBW4', 'B08Q9WLMNQ'],
#  ['B09TNKHM3P', 'B09TNBZ3WV', 'B09TNJVSWM'],
#  ['B09TZZ6M1M', 'B08H8968DN'],
#  ['B08NWM5VFW', 'B01N6WV6ZM', 'B0BFPHKCK6'],
#  ['B0855GX167', 'B0855GX167'],
#  ['B003ZGBHVC', 'B00WB0GEJS', 'B0030UGKRY', 'B0030UGO6G'],
#  ['B09ZYFNVPL', 'B07MBPZXXV', 'B096M7MD5Q', 'B089NT8C7W'],
#  ['B00GB0HK0G', 'B00FJ33VRM', 'B00GB0HOV6', 'B00GB0HK0G'],
#  ['B07FPT7RS4', 'B01MV028B3', 'B09PN1Z1TM'],
#  ['B09D5PJW29', 'B09X1L1RM5'],
#  ['B082BH6K1D',
#   'B0932XCZNC',
#   'B0932WNWLL',
#   'B082BJ4LSW',
#   'B082DKQQX8',
#   'B082BGLFHH',
#   'B082DK5W6Z',
#   'B0821HJMX5',
#   'B082BGTHP6',
#   'B0797QCXTJ',
#   'B07N9FFY52'],
#  ['B00G7T0IPU', 'B00G7T0IPU'],
#  ['B08L9JQ2CP', 'B08L9H5KNB'],
#  ['B0B117LY53', 'B0B7HZCBR5', 'B09F6DQTH8'],
#  ['B06XS3FRNR', 'B06XS366LQ', 'B06XS3CL5N', 'B07N6K8DTP'],
#  ['B0B5L5FRRV',
#   'B09TP3J4W5',
#   'B0B2JWQQGR',
#   'B08BC6M893',
#   'B0875ZFC8K',
#   'B0B1V9MNWC'],
#  ['B08775CVH4', 'B08B8TQ94J'],
#  ['B00004OCL3',
#   'B00L9X4WCE',
#   'B00940DUE0',
#   'B07PVXP24Z',
#   'B09872VX9H',
#   'B0B7JHQF5L',
#   'B00004OCL3',
#   'B00L9X4WCE',
#   'B00940DUE0',
#   'B00004OCL3',
#   'B003M8GMS6',
#   'B00940DUF4',
#   'B00L9X4WCE',
#   'B09MHJN3W9',
#   'B09KZRQN6D',
#   'B09S3R1SZR',
#   'B09S3PKWDH',
#   'B07PYPGX6R',
#   'B07PWHLDHB',
#   'B07PXL8GY9',
#   'B09YNBLK78'],
#  ['B09BNSMW1W', 'B0B5GWD8GJ', 'B08BCG7C4Z', 'B09BNXB16W'],
#  ['B09R1MPGDN', 'B09G293QT7'],
#  ['B09XTSHBKR', 'B0BCQ4QWWV', 'B09M2TR157', 'B09M2432WR'],
#  ['B0B5W12LQT', 'B0B5W12LQT', 'B09RQVDVQ8', 'B0B775GFDL', 'B0B3XGGYJY'],
#  ['B07K2PK3BV', 'B08GY7NPYN'],
#  ['B0B8JSDF7N', 'B0758BMRHY', 'B0B8JSDF7N', 'B0758BMRHY', 'B08VRFF5NT'],
#  ['B0BGH7SSRV', 'B0BGHBCVR9'],
#  ['B01K1YG8L4', 'B08ZJPVZF3', 'B00H9IRWSY'],
#  ['B07PPQP46V',
#   'B07PRZ9XQ5',
#   'B08NDQK56R',
#   'B0995D5MWJ',
#   'B0995D9C57',
#   'B09NKD7XQH',
#   'B09NHQVDLH',
#   'B09NKD7XQH',
#   'B09NHQVDLH',
#   'B09NHQT6QC',
#   'B09NJHW7WH',
#   'B09P38XL99'],
#  ['B088K3DF69', 'B0B8SKT7NB', 'B07FQD9YX2'],
#  ['B08XBR1PTN', 'B09Y1VPG5Z', 'B09CYZRKD6', 'B0B5KXVY2P', 'B08YN2GDQQ'],
#  ['B08TCFBDHC', 'B098PCW1MV', 'B0B14XMXPW'],
#  ['B09XVHD56K',
#   'B09XVHD56K',
#   'B08JV9NCPB',
#   'B01BKK5UG2',
#   'B01BKK5UI0',
#   'B01BKK5UG2',
#   'B003996648'],
#  ['B095SGJ3XD', 'B095SGNBZN', 'B095SGJ3XD'],
#  ['B077PD5W25',
#   'B08CC335NY',
#   'B07DGYX438',
#   'B08YLZN3HC',
#   'B00000JICB',
#   'B01NAWU228',
#   'B07M7L1SLR',
#   'B09P4TRQ6F',
#   'B09FJJ1M17',
#   'B08GPSVHWM',
#   'B0895PBJCQ',
#   'B098924VGL',
#   'B0895PBJCQ',
#   'B08GPSVHWM',
#   'B0875LM61M'],
#  ['B000GFEYU6', 'B000GFEYU6'],
#  ['B07DKFHHFN', 'B0B96YVZC1'],
#  ['B07THHQMHM', 'B0B3QX469C', 'B0B6BY7TTV'],
#  ['B07NV3X8LF',
#   'B01M9IQZFV',
#   'B07ZTLJBVQ',
#   'B0977FMV87',
#   'B07K7NBK7H',
#   'B07K7M256G'],
#  ['B09WYBCC1Y', 'B09WYDJ15D', 'B07TJSD3BH', 'B07TMZ842S', 'B085ZMLVTY'],
#  ['B009DGO30K', 'B003JBRQ9A', 'B06X3W2LX7', 'B09JT4H3H7', 'B09JT4H3H7'],
#  ['B0B5ZNWXJ5', 'B0B5ZR9B31', 'B07VJLH7D1', 'B07VKYJRBQ', 'B07VJLH7D1'],
#  ['B082HCJY5T',
#   'B081JY8Z7J',
#   'B000IU40HQ',
#   'B0B6FBGJWY',
#   'B01CRBEUVO',
#   'B00D4R563M'],
#  ['B095SYWNHJ', 'B095SYWNHJ', '024126264X'],
#  ...]

# %%
unique_items = list(set(i for j in interacted_items for i in j))
unique_items
# Out:
# ['B09BFL6722',
#  'B0BGHF2KVT',
#  'B002WRICCC',
#  'B09BT6YRQG',
#  'B004345SP6',
#  'B0998VCH5B',
#  'B07RYTSNDV',
#  'B01MG4DM91',
#  'B07NZ6VCZG',
#  'B09L5PM418',
#  'B09X4QDSDF',
#  'B005AE5600',
#  'B08XKM7VLM',
#  'B07VV9HGJ5',
#  'B09M8K4RYQ',
#  'B08D3VDBJG',
#  'B075S9MYQ9',
#  'B0B584VQXS',
#  'B00KHT0SUQ',
#  'B0BGFHC5NR',
#  'B07TMLZ7VQ',
#  'B00PC9UZY0',
#  'B08DPNG346',
#  'B08HM9T6PH',
#  'B00JJLZHLI',
#  'B07HYSJW56',
#  'B000IU3W1G',
#  'B09YMK6X5M',
#  'B074YKX2MG',
#  'B00MGHITSU',
#  'B08X282LQN',
#  'B08H2B1VWC',
#  'B08JL4D3C1',
#  'B09B2YRXCG',
#  'B07NZX471W',
#  'B09H69Z3TQ',
#  'B0867W5KY9',
#  'B00H9EZEEM',
#  'B0B971D75B',
#  'B084Z3HGTV',
#  'B00Y0QDEJE',
#  'B0B4KGGWZC',
#  'B08QVKBNXN',
#  'B004X9Y4VU',
#  'B09NZYC8CP',
#  'B0972Q55TJ',
#  'B00IL0QT1U',
#  'B08FC6HHD7',
#  'B083B6R4FW',
#  'B018W7URNC',
#  'B09PL6QZLF',
#  'B0BFP9KV5D',
#  'B085NMQT75',
#  'B09GYRK5GR',
#  'B0BHS8PKPY',
#  'B07DGMSLHF',
#  'B000NVRDL0',
#  'B09ZQPYKLF',
#  'B09P9Q6DWJ',
#  'B013W32G6W',
#  'B01KI4O3H8',
#  'B08JVHQMMV',
#  'B09MQGBHGJ',
#  'B0954SS5SW',
#  'B079RLZRRM',
#  'B09W191194',
#  'B09N3QKZDR',
#  '0198423462',
#  'B08PP6V1HS',
#  'B09T614YZS',
#  'B09GW1QNC9',
#  'B094YH67X4',
#  'B08FRJBSHQ',
#  'B094DS6VMQ',
#  'B09BT8RYWN',
#  'B0B52DKD17',
#  'B095CNZBS2',
#  'B0013G4IFS',
#  'B09TL2N86W',
#  'B01M7W1CD5',
#  'B07XNL8YP1',
#  'B08SR5HZBG',
#  'B0833MNPRP',
#  'B08G9ZTSS6',
#  'B09135N2RM',
#  'B08DKFX4GT',
#  'B01L7IIHY4',
#  'B09W9WFWQ3',
#  'B07FBX5RYT',
#  'B01JUYDEEU',
#  'B0B28PR2LP',
#  'B0BG8GSKG5',
#  'B099WZNSBG',
#  'B08CXV1D65',
#  'B001O1FQLW',
#  'B09ZPJ5C5S',
#  'B07WFDQ56L',
#  'B09VPGJC4J',
#  'B09GYQ28BK',
#  'B07R623QWJ',
#  'B091KF3WNN',
#  'B0B63PHYW9',
#  'B08TC13SR1',
#  'B083LN88F8',
#  'B08W3QVGWN',
#  'B07S4N6W2S',
#  'B07PP1X4MJ',
#  '1780556454',
#  'B082VT4GL6',
#  'B01D8FI852',
#  'B01ASWB8CS',
#  'B08Y6RS3L7',
#  'B07WJYYHPH',
#  'B072KZYFHK',
#  'B01FFUNDXA',
#  'B08L819DV5',
#  'B002YJW382',
#  'B08T1Y7ZGJ',
#  'B01AWOX65E',
#  'B09GB67MBB',
#  'B08S3JSRT1',
#  'B08JL46MLS',
#  'B0BJ936VH6',
#  'B0BK9VN833',
#  'B01JA8W6E0',
#  'B089DC8GGY',
#  'B07QLRHG14',
#  'B06X9Z6671',
#  'B0074O7FK8',
#  '1838033998',
#  'B089782NDT',
#  'B09DVHS9YY',
#  'B0B46NY76D',
#  'B00M0KILOA',
#  'B09TB5PHTC',
#  'B08KHHVZWB',
#  'B001V8IJ2G',
#  'B08Y69M98N',
#  'B0B4SP858H',
#  'B01BLUETRM',
#  'B07197DNFB',
#  'B0BHT2NX68',
#  '1789083591',
#  'B09MDD6FFG',
#  'B00GRXFX42',
#  'B09ZHZSLCW',
#  'B005IDBPK8',
#  'B0B1DL3WN5',
#  'B018WBUJBS',
#  'B084C4JYPT',
#  'B083HPHQPW',
#  'B07MDPXFQC',
#  'B0BD427FSF',
#  'B0B4SC8C6D',
#  'B00MOA1R92',
#  'B088MFM578',
#  'B086JQPX7T',
#  'B014QU0ZT0',
#  'B017TDXN54',
#  'B07KP1VK61',
#  'B096KT6XXM',
#  'B07L94C2VV',
#  'B07FKFHGWS',
#  'B09N3CRRZS',
#  'B07R8BB48F',
#  'B08V8BNBSX',
#  'B07NDYQSL5',
#  'B08WTKM4XM',
#  'B083ZJSM3J',
#  'B0863391CD',
#  'B082PKKT21',
#  'B09Q8DQ3JL',
#  'B07QDNKSP2',
#  'B09Y8YCRHN',
#  'B07QXM2V9X',
#  'B07PG8H3RK',
#  'B004KU834G',
#  'B08ZF7QDXJ',
#  'B01E69NMP0',
#  'B00201U5D4',
#  'B08LW3QGFY',
#  'B00LTQBDVY',
#  'B081SXLD63',
#  'B09DKTBSXH',
#  'B09KC7VFXX',
#  'B07PVGQQRB',
#  'B07L5RCDV3',
#  'B00X9G6K1A',
#  'B095CQCBLW',
#  'B07XRF3KRP',
#  'B000ILEVWO',
#  'B08X66XV2T',
#  '1780557760',
#  'B0B7RF5K4Q',
#  'B086PSB6Q3',
#  'B09316DC61',
#  'B086VZ9H2Y',
#  'B09DPHWDV1',
#  'B08C5NJBWR',
#  'B07GZP8T6L',
#  'B087JMHNS9',
#  'B08XJG8VV5',
#  'B09H29XTZG',
#  'B01LF4Z5LS',
#  'B086GFFSMR',
#  'B094YK3791',
#  'B07VTDXFDC',
#  'B005RQGZTW',
#  'B083RDWJPD',
#  'B0B2VQGSS6',
#  'B08CHZN5NB',
#  'B09474M67W',
#  'B01BF6S1GC',
#  'B09NPYG389',
#  'B07DW7R9V8',
#  'B096RQDQXT',
#  'B08RJDVYH6',
#  'B08Z8CSM1R',
#  'B0BDLWR2M7',
#  'B07WZVN36D',
#  'B0BGQ2N9GC',
#  'B08T9MK72Y',
#  'B077ZWN4V1',
#  'B072DS462V',
#  'B09D2SQJZ9',
#  'B08ZC7921N',
#  'B0BCZSDP5V',
#  'B083L97PNP',
#  'B089FBW11J',
#  'B07K7NHNPL',
#  'B07W4PM8T9',
#  'B08V8FVMXR',
#  'B09MQJNSQM',
#  'B0794VMZ8G',
#  'B0BJPF9NXQ',
#  'B01N0XC93X',
#  'B071L7RFYN',
#  'B005H0RFTM',
#  'B0B3STZKPT',
#  'B09L1PY1MV',
#  'B09MTYVLG5',
#  'B08D39SX4M',
#  'B00HSJGHB2',
#  'B0B384BWM4',
#  'B08XCKVXL8',
#  'B0001IWX9M',
#  'B09Q11W4ZF',
#  'B09NC4H4GH',
#  'B0165CDOWC',
#  'B00F0MRPCO',
#  'B09CDCVTZS',
#  'B07BRJWB9Q',
#  'B078HSD8ML',
#  'B0BB1ZJMY2',
#  'B09JBD6DPX',
#  'B09SF79QPQ',
#  'B07XTNDRCD',
#  'B0BBH3V8YY',
#  'B0BC3MCBS8',
#  'B0BFMBNLYT',
#  'B06WP71TVN',
#  'B07M5LSHPG',
#  'B07W4KTD62',
#  'B07Y9LPN6H',
#  'B09S5Z42J7',
#  'B095BQJZ1Z',
#  'B09N4XV1X6',
#  'B082CBZQNP',
#  'B093WSMF4P',
#  'B09BF2XC44',
#  'B09NB1SMVK',
#  'B072FJVSSL',
#  'B00PSPLWUO',
#  'B08CVSB2RL',
#  'B07KB3HYV3',
#  'B0058XX3BW',
#  'B07SC2NQBH',
#  'B09ZK6F6JM',
#  'B07T1CLCHS',
#  'B07ZFRRN62',
#  'B073Q73B9H',
#  'B09K7XPTZX',
#  'B09WDXN6DK',
#  'B01GFQ5ZFC',
#  'B0BF49M42H',
#  'B08R7TVPD6',
#  'B086FDMG6X',
#  'B0845QKVHC',
#  'B09LBZWNF6',
#  'B07735DC2M',
#  'B08KJK7DJX',
#  'B08Y942TCZ',
#  'B07QZ4KDLZ',
#  'B002UNJ8EO',
#  'B0928QGW8Z',
#  'B09MDG9VGM',
#  'B07K2SPCQD',
#  'B09NHTQ28K',
#  'B01LXLAVH2',
#  'B099R77XQB',
#  'B08GFWMZV3',
#  'B07GDHPPN7',
#  'B09LH7XX5K',
#  'B087TRSGZ7',
#  'B09TXNZVD3',
#  'B093Q9N9CQ',
#  'B09FP766XQ',
#  'B087R4GMKZ',
#  'B09TF3BZRG',
#  'B081DS6WW7',
#  'B0874CJ3VM',
#  'B0875X8C4Z',
#  'B0B6BXW435',
#  'B07925YD53',
#  'B08KD2CB44',
#  'B093Z4MVXV',
#  'B091V3CNTQ',
#  'B07B7K1WLG',
#  'B088987LVY',
#  'B00CAAYW98',
#  'B07CXKGG1Q',
#  'B09B2BZRRN',
#  'B07NRXZ1Z7',
#  'B014KXGN8A',
#  'B09M6X9CBT',
#  'B07KXMFCLS',
#  'B0B77S4ZSK',
#  'B07XD6BYSC',
#  'B09NNKB78F',
#  'B0BG6Y49RR',
#  'B07JVCB55L',
#  'B08MXG8ZGX',
#  'B098T9RF7T',
#  'B08PBZGGZQ',
#  'B01N3LX0FU',
#  'B08V17RFDW',
#  'B0B3WKNZ31',
#  'B07CXQ1MXW',
#  'B09M7FNQ19',
#  'B08MXT4RHV',
#  'B09ZLJKN5S',
#  'B086PLR8RF',
#  'B00ZFCR26S',
#  'B01C7PLXW4',
#  'B07VNMTJXX',
#  'B096TY3SZ5',
#  'B0BJYGDGGL',
#  'B00DZO538C',
#  '1648370535',
#  'B09XBM6DBX',
#  'B08C1L3V39',
#  'B00N1Y7ZZ0',
#  'B00BE4HOIM',
#  '1529409713',
#  'B09BZP831W',
#  'B0B3FB7SQ6',
#  'B07WTV4CQF',
#  'B00R0DLFNG',
#  'B08DD1KZZG',
#  'B0BGHWZQCL',
#  'B08HT3CSTM',
#  'B08VX3RPQJ',
#  'B07CY424RP',
#  '1119345235',
#  'B09T9BCHWG',
#  'B0BCFRRFF5',
#  'B08FBF1V96',
#  'B09CPNTYX8',
#  'B0B5PC63L7',
#  'B09B3QSY36',
#  'B00DVPS4IQ',
#  'B09PFVS171',
#  'B09PYK7JNZ',
#  'B01JOKWUK4',
#  'B01NAJ503A',
#  'B07MXJTK4H',
#  'B086GZTB9C',
#  'B07WGW5YM5',
#  'B08L7SNLDP',
#  'B0B21Q8354',
#  'B08KDS41TK',
#  'B081MT4HBR',
#  'B00667TH82',
#  'B01FFX6G7M',
#  'B01B7SNAWS',
#  'B087M3M7T3',
#  'B00023TBDM',
#  'B07QQZD49G',
#  'B09H3794GH',
#  'B08ZCRLNYY',
#  'B079BX6X1Q',
#  'B08FBDLYF1',
#  'B08Z4BPJJG',
#  'B0031RS3YO',
#  'B09H7NLTGP',
#  'B09NQ2JNPQ',
#  'B0009K4IS6',
#  'B09T61FB44',
#  'B0BK6FNWXT',
#  'B08KS69XYS',
#  'B096XJPRWP',
#  'B07RZ2YML3',
#  'B09C28TGLW',
#  'B09YQS574L',
#  'B0BC2B91VF',
#  'B09VX8M62Y',
#  'B0BD81FDJC',
#  'B0B5XK37XW',
#  'B07HG8JHNG',
#  'B0718SLGF4',
#  'B09J2H9WTF',
#  'B001DZRKJU',
#  'B011P3QXBA',
#  'B0BCQL5BSH',
#  'B09D7QR411',
#  'B09VC3K4LF',
#  'B076HF9BC2',
#  'B0B4NXQ9JC',
#  'B07KKF3CMD',
#  'B00114MEJ4',
#  'B01H93LMHA',
#  'B08FN3P3Q5',
#  'B0B7MRJVNB',
#  'B087Q8BS2V',
#  'B088B9T6CH',
#  'B09XMZ817V',
#  'B0792YKLLF',
#  'B01BZ20FE2',
#  'B09HTS1J2R',
#  'B09G94HLLZ',
#  'B088BHKX2M',
#  'B09JG7L64B',
#  'B09C63Y8Q5',
#  'B01M0RRSB6',
#  'B09JX1H6XN',
#  'B085LXD6T1',
#  'B09QT53V7T',
#  'B08QMZ8G29',
#  'B0B6STFJ9M',
#  'B01IB2S9KG',
#  'B00U2OJO1A',
#  'B07BC3QKNF',
#  'B09G2YNXP8',
#  'B08BJ71359',
#  'B00FBUK784',
#  'B00Z7VLGL4',
#  'B000WZT1SK',
#  '9655981045',
#  'B085L82ZDP',
#  'B08YDMGWTS',
#  '0439023491',
#  'B07ZV657LT',
#  'B0956YRZQ7',
#  'B09FT4XMP3',
#  'B09XVL4WR3',
#  'B07CYVCQBC',
#  'B01HOD3ZNO',
#  'B0060KTXDE',
#  'B07BH51982',
#  'B0B15G16VP',
#  'B079FTQT4T',
#  'B08BC1ZT1J',
#  'B07HHBS1XR',
#  'B092H8XHDG',
#  'B07WNPVCJB',
#  'B00GFT0TBU',
#  'B08ZNNGL75',
#  'B08R7LL1H8',
#  'B072NBS4W4',
#  'B097KCNL2V',
#  'B000I6PL28',
#  'B07T5SVNXF',
#  'B0B3XNXK6P',
#  'B0178EZN1Q',
#  'B0BHSLSCZX',
#  'B004OBZRPO',
#  'B08LHG4VNG',
#  'B08P3CQNMY',
#  'B08HN4JKZ5',
#  'B0B69111DL',
#  'B07JR42V5N',
#  'B00PC5EO28',
#  'B073S42J5C',
#  'B0BDTBZ68Y',
#  'B07MCMTJWC',
#  'B0BD88NYWZ',
#  'B08L6XMNXB',
#  'B08KS7Y6HG',
#  'B07VV5MR4F',
#  'B0BB6H4G9S',
#  'B00J7VNRQM',
#  'B076ZFQZ3Z',
#  'B07KT6LF5J',
#  'B00KHVJY6S',
#  'B0B4T5QBW4',
#  'B07D5FT84H',
#  'B09FXSN8BC',
#  'B07Y8LNKD6',
#  'B098PCTJ8X',
#  'B087BC219G',
#  'B0B7L1YZX3',
#  'B09WM3C4FS',
#  'B00006IEEU',
#  'B0B18WTQZD',
#  'B0059170BC',
#  'B0B51QNN1P',
#  'B00ET1HK7C',
#  'B00UAWLL0Q',
#  'B096T1PNLQ',
#  'B08MWLTPNK',
#  'B08PYVY8TC',
#  'B09NKRB8VJ',
#  'B08QTY3JBC',
#  'B094342JBW',
#  'B08D3MRM7B',
#  'B08DG58NX3',
#  'B0BHKN8XY1',
#  'B08NPQ6CHW',
#  'B09J915B59',
#  'B09KTK54DF',
#  'B09CYN5L4G',
#  'B00MTGGYJ4',
#  'B09R3D1QF7',
#  'B01KJZVTA0',
#  'B0B88KQQCP',
#  'B099997Q14',
#  'B09D2XQKMR',
#  'B08L5Z16RG',
#  'B09KDMCFDZ',
#  'B07N7GDFDG',
#  'B08XZ3FRN8',
#  'B09BD1VJD8',
#  'B08438XNVG',
#  'B07Y9QXVS2',
#  'B09JJG5BCV',
#  'B011ICK0JY',
#  'B0B7B4NN84',
#  'B07HY29775',
#  'B08X779949',
#  'B079CZC6SC',
#  'B009GILSN0',
#  'B08KLY926G',
#  'B0BGJCDL4H',
#  'B09CGLVRZM',
#  'B07XNWDFV7',
#  'B01LZPH3CO',
#  'B0050EB0Q4',
#  'B09ZDBF8JH',
#  'B08CTK4247',
#  'B09XV6KV79',
#  'B08BHXVR5F',
#  'B08XXX67SK',
#  'B09HYYG5QM',
#  'B01N4PDQM9',
#  'B0BBT7N4P6',
#  'B08GQ17N9V',
#  'B07QPXMP2G',
#  'B0BFBKH9F6',
#  'B08KW5D8YS',
#  'B08MTLWFC7',
#  'B0BG5TY5TM',
#  'B09ZXB6H7X',
#  'B07NXVTSFC',
#  'B08C31C5FG',
#  'B08R8CY938',
#  'B07QDTJHPC',
#  'B0019M7OCA',
#  'B09Q1ZRWMN',
#  'B077YM7JP2',
#  'B013WZGG2K',
#  'B07QS4N5FD',
#  '1912342766',
#  'B000NE2UH4',
#  'B083G6JWDN',
#  'B0B97L77S2',
#  'B08HYZPT44',
#  'B0B4G9MJXS',
#  'B07LFSNFYZ',
#  'B00RCCAPPE',
#  'B076P1X4B1',
#  'B096G6F4MW',
#  'B07H4DG6FL',
#  'B09S3X3BFL',
#  'B077J6W8XZ',
#  'B08BC7GNW9',
#  'B01LXIYUSR',
#  'B09KS1YW2Y',
#  'B008JZQZ8O',
#  'B07TZJWF1W',
#  'B00N3UICBS',
#  'B07BSZXWWT',
#  'B097CDGGT3',
#  'B0768XMLXG',
#  'B09YCCDKDB',
#  'B071FM3N1Q',
#  'B09PDK1GZX',
#  'B09FFR52BN',
#  'B07GXTZLD7',
#  'B074Z6DGT2',
#  'B08BTXZGK7',
#  'B09C1J8X42',
#  'B094QPD3V2',
#  'B00FYXB4A8',
#  'B09PY61KLS',
#  'B08DM2846C',
#  'B07Z95KQD6',
#  'B08SR3KRF9',
#  'B0BJCYL5R4',
#  'B09RKB2VKT',
#  'B07RCKL9G2',
#  'B015OJ8J5O',
#  'B09MJ26G2T',
#  'B0721QLBW3',
#  'B0B7WPV6J9',
#  'B07VM78Y58',
#  'B0B8ZNB38X',
#  'B000GGKPWQ',
#  'B0BHF9YSR1',
#  'B077Y429TF',
#  'B09QCNVXC1',
#  '1407170759',
#  'B097NWR3NF',
#  'B08LMNF8XK',
#  'B08YJ6LGD6',
#  'B08C9Z175Q',
#  'B0B7C1FX8H',
#  'B07L426S5D',
#  'B0B8HT3CNX',
#  'B09F3NWZPN',
#  'B0B1HP28RW',
#  'B09C6FG128',
#  'B093L4Y123',
#  'B0B7RTN8HH',
#  'B07XM835DP',
#  'B09GYLBH1Z',
#  'B077MHLCFS',
#  'B004VLA3WY',
#  'B09JX25JPK',
#  'B07D5FT61P',
#  'B07F2W8YBV',
#  'B08PFZT1MV',
#  'B07ZXCX2BZ',
#  '0008353905',
#  'B08QSLRD59',
#  'B095BRHR7X',
#  'B07D8D6T53',
#  'B09TSXNKGL',
#  'B00486K50C',
#  'B09TSMNGSM',
#  'B0BBGRDM5X',
#  'B099KRF58V',
#  'B000BB56B6',
#  'B09JS8TNW3',
#  'B07QG2R4PY',
#  'B00KSP9QE8',
#  'B08YP9XXNP',
#  'B00F40XA80',
#  'B002120NAM',
#  'B0B5L5ZBPG',
#  'B084J7MPXJ',
#  'B082XKBT67',
#  'B00MILO2O4',
#  'B06VVW876B',
#  'B08QH1VG6V',
#  'B01CZ9H7PY',
#  'B09G9XRG1C',
#  'B07KM377KY',
#  'B07Y1H52Y2',
#  'B093PB79LN',
#  'B09NMZK81P',
#  'B07G95FFN3',
#  'B09XTGRHR5',
#  'B08CB33RMK',
#  'B0183SX3YK',
#  'B092DLN74T',
#  'B08K7K21LW',
#  'B00VIU0F24',
#  'B081NN6L4M',
#  'B0BD96C39K',
#  'B09N28S97N',
#  'B072B8WN34',
#  'B099R9R136',
#  'B074Q2W212',
#  'B071GRPBY1',
#  'B0915X4C4B',
#  'B07QXNJ7SC',
#  'B072PZYKC5',
#  'B07KTHPK3W',
#  'B0BDCSW57Z',
#  'B08RDL673L',
#  'B001IS1XFE',
#  'B0B3JJD6FB',
#  'B094D8LMHT',
#  'B0B6PJZ5H5',
#  'B074HQP3BR',
#  'B08XJ2PW73',
#  'B09NDVM2TX',
#  '9124371882',
#  'B00OYTTG1M',
#  'B01MYQESJ7',
#  'B08LMZTXRQ',
#  'B0868V8Z4Y',
#  'B08Z8B2M38',
#  'B0B74WQDH4',
#  'B005DJXYY2',
#  'B074SYP8BL',
#  'B0B9KMKHVX',
#  'B08CBB4V9W',
#  'B0001P0FHC',
#  'B07KZ9XR64',
#  'B07FWYNHV6',
#  'B09F3NS7YB',
#  'B07W3RSC1J',
#  'B00MCSVUZC',
#  'B07NTT4GQ2',
#  'B078SVT42Z',
#  'B0BFG3D3V4',
#  'B08D1XFD68',
#  'B08JC7V81H',
#  'B09BR41LF5',
#  'B09JFK6TSG',
#  'B0BBWGL3TJ',
#  'B00FGCRSXY',
#  'B09535NZGH',
#  'B07RPT338J',
#  'B09PMCRXHV',
#  'B091Z7R2YJ',
#  'B09MT83T6M',
#  'B08S44KXQB',
#  'B093KVX6ZH',
#  'B09LT5CQSD',
#  'B085S7NFZV',
#  'B09BB6LPLV',
#  'B001RH2RW4',
#  'B08L6NCPPL',
#  'B0BHTNMNJG',
#  'B089M9LPTN',
#  'B076N313XV',
#  'B096ZQFPC3',
#  'B0B6Q41GJP',
#  'B09BC1GPBJ',
#  'B07SRJ12Q9',
#  'B07DJ2T739',
#  'B08MM5QWH2',
#  'B009SKM7FY',
#  'B08R1NF3BV',
#  'B08FJ7XY3B',
#  'B093GWLNFJ',
#  'B09TW8HZ3M',
#  'B00YU6PGA4',
#  '1911624016',
#  'B09NR1S572',
#  'B086BX7LVB',
#  'B08387CLZN',
#  'B0822RBC35',
#  'B09JNLN134',
#  'B01MTKIU8Q',
#  'B08L1185RN',
#  'B07DCKLLYY',
#  'B09BVMZ9FQ',
#  'B07M5DC5H1',
#  'B09CY1KGSW',
#  'B07ZR6YPHB',
#  'B09GKKN2TC',
#  'B086333GRQ',
#  'B08P9Y7Z9D',
#  'B075S49XY6',
#  'B082XPY1N6',
#  'B08L9R1XXB',
#  'B07DKH9JDW',
#  'B07DFDP16Q',
#  'B09TK39FKJ',
#  'B07WTXYHW7',
#  'B01BX0UF1Y',
#  'B01D5SI9RO',
#  'B0B84T5D6J',
#  'B09DK2CMRR',
#  'B09RQ33HVM',
#  'B09KGS7BBH',
#  'B00NEKRON4',
#  'B07YG622LP',
#  'B093G1PV6T',
#  'B09888B5M6',
#  'B09Y8L6PTQ',
#  'B004TWCEYK',
#  'B08GCWKGMV',
#  'B002Q134ZE',
#  'B09FTKKXPG',
#  'B07GZGPR3F',
#  'B091D117GH',
#  'B097ZMFDHZ',
#  'B007TKDZUG',
#  'B0843B4Y32',
#  'B0B82N18CK',
#  'B09JCD5DTN',
#  'B07GPHS9XQ',
#  'B079DNJX42',
#  'B08D3SV1K1',
#  'B08HHBKPFR',
#  'B09FKJ6WWK',
#  'B01K1GTHLU',
#  'B089CKRDZS',
#  'B073W7Z8CB',
#  'B07FXPY28T',
#  'B01EJKX6UM',
#  'B004BFX5TS',
#  'B08DHCSDWS',
#  'B097HDHC5G',
#  'B0915C4LJW',
#  'B0089LGWPE',
#  'B07HGQDWWC',
#  'B086D1L91P',
#  'B09F1NLBHT',
#  'B0B1HTBHKY',
#  'B0006UF6D0',
#  'B018F4EE7W',
#  'B0B5ZL73ZQ',
#  'B07D16KPHJ',
#  'B09BZ2287D',
#  'B0B291FKLS',
#  'B07QQZCX84',
#  'B07WJV2KBB',
#  'B09Y2VDZ26',
#  'B09PFXYBM6',
#  'B07NSY2KBS',
#  'B00CN7071U',
#  'B07Z3CKVRX',
#  'B09QM1W17V',
#  'B08T1PQTBZ',
#  'B09VGJ4R53',
#  'B08MFLJHK7',
#  'B0B2RP1N4F',
#  'B01DN8TEA2',
#  'B09YHYNRXC',
#  'B00HJ9HH0Q',
#  'B07N9MDR5B',
#  '1922616621',
#  'B00AHXYEMK',
#  'B095SMJTB8',
#  'B0B213N9F3',
#  'B07BZZD77X',
#  'B093H1STDG',
#  'B07VGQ9S5Y',
#  'B085PQCF62',
#  'B096DXG94L',
#  'B07FXZW3TV',
#  'B07ZYVVZKD',
#  'B0972DZ595',
#  'B08H18G1ZJ',
#  'B09J9CT2GJ',
#  'B09ZJ3CMLJ',
#  'B00KWCQCFS',
#  'B00JNQ96KC',
#  '0008551545',
#  'B07MN1B5WG',
#  'B0B51QN756',
#  'B09CPW5W93',
#  '9123881275',
#  'B0B6JMTXBY',
#  'B09KXRPPDF',
#  'B07SNFXHQ8',
#  'B07YX2G22Z',
#  'B01NCB0KKO',
#  'B07XLN881X',
#  'B09ZXXG9WY',
#  'B0065TQDY2',
#  'B09Y92D4QQ',
#  'B076GYP4HG',
#  'B083Y521CH',
#  'B08R6QKYNS',
#  'B09J1C5H23',
#  'B08B6C2BN7',
#  'B081TMPY8P',
#  'B07PT7VL86',
#  'B09WV5N59F',
#  'B08XD4FN2K',
#  'B0BJPWG6MK',
#  'B0B79WNY3K',
#  '1472294114',
#  'B001E97AX6',
#  'B07K4GV8LV',
#  'B0B1MH4GCH',
#  'B0B18CZD4S',
#  'B0014KXKJI',
#  '0008532125',
#  'B00OD0UAL2',
#  'B0B1VQHQ5Z',
#  'B09YH7Y1S5',
#  'B07955QLBZ',
#  'B09K4KV6JH',
#  'B081HGJPLL',
#  'B09V2DCQDC',
#  'B07V3JZ6DX',
#  'B09XMVH15C',
#  'B09GFQ51G5',
#  'B0B5DGGTZ8',
#  'B01985N4T6',
#  'B016WINB2C',
#  'B01LZU5FYW',
#  'B09KR7JM55',
#  'B08R7SHF9W',
#  'B09KY1S7YW',
#  'B09MFDNSDP',
#  'B00D87F1RO',
#  'B00FZF6P18',
#  'B083V2ZZ6F',
#  'B0027XNA6Y',
#  'B07H5577BP',
#  'B07PJ561FS',
#  'B0B9G1TR4M',
#  'B0BCP115JF',
#  'B07YRTNN2Y',
#  'B09GM1JYSQ',
#  'B09H313JBJ',
#  'B0B7D5MD1Y',
#  'B097MFZFLQ',
#  'B09CYBZ81J',
#  'B098687L26',
#  'B01N7NBC0I',
#  'B0BCFLVN4W',
#  'B00CS0ZZWS',
#  'B000WHWF9A',
#  'B07JZZ366C',
#  'B0B12PCRGP',
#  'B084RSC1GL',
#  'B0B6V9D89F',
#  'B09MZ3J3B3',
#  'B09V7GCRCF',
#  'B07D49BRSD',
#  'B084BSRZQX',
#  'B0874D5GKP',
#  'B09BK11ZFL',
#  'B091BV3XQB',
#  'B0B6BMJQPR',
#  'B0B1JG562P',
#  'B00KY1VQYE',
#  'B006S6TRMM',
#  'B09JKN3TMW',
#  'B08YNYGCLN',
#  'B07TT1RWVF',
#  'B01LHXFLAW',
#  'B0B3XKL1LC',
#  'B00WAJBJIQ',
#  'B07MJLQJKD',
#  'B085RMRVCQ',
#  'B016IPBXQU',
#  'B09923GSFK',
#  'B08G1T7B14',
#  'B07B8GC6K8',
#  'B0B38Z8KKP',
#  'B08C34QRNH',
#  'B09NNLLR59',
#  'B081635ZLF',
#  '1446304787',
#  'B0B7BGQV35',
#  'B09PQHMNS3',
#  'B0B59HBLPM',
#  'B09YF5LHCH',
#  'B07QPZDYTV',
#  'B07FDPPM17',
#  'B09Y175YQP',
#  'B0B9SXVWPT',
#  'B09ZQNBW82',
#  'B0070YSHK4',
#  'B0B6PK3KV2',
#  'B0BC9PDDHB',
#  'B0B8THTXLZ',
#  'B003HKT42A',
#  'B09TNPKSK8',
#  'B07XHLD517',
#  'B0009K4IWW',
#  'B0098KQ2G4',
#  'B09P67W71X',
#  'B0854MP3LB',
#  'B094FFWX38',
#  'B085NYGNXD',
#  '1421599449',
#  'B08K351362',
#  'B08P329Q63',
#  'B085LMRK3G',
#  'B08B3TQZKS',
#  'B07T3QN5QG',
#  'B09FL6YS5W',
#  'B09KZFH6ZB',
#  'B06XDD6R4Y',
#  'B08BYQB7N7',
#  'B0755X2STP',
#  'B07CHNFZMT',
#  'B06XJK9MGD',
#  'B07LH3FDD3',
#  'B07CTCJBWL',
#  'B0719R32DY',
#  'B099PHPW9N',
#  '024137166X',
#  'B0B46TYF6B',
#  'B005Q737SO',
#  'B07RQ6SKJX',
#  'B08S75JPFB',
#  'B07RZL4STB',
#  'B07S9FXKZQ',
#  ...]

# %%
len(unique_items)
# Out:
# 470148

# %%
# Check unique locations

products['locale'].unique()
# Out:
# array(['DE', 'JP', 'UK', 'ES', 'FR', 'IT'], dtype=object)

# %%
# Exctract the English products only (UK)

products_eng = products[products['locale']=='UK']

# %%
products_eng = products_eng[products_eng['id'].isin(unique_items)]

# %%
# from sklearn.model_selection import train_test_split

# %%
# products_eng_used, products_eng_unused = train_test_split(products_eng, train_size=0.5, random_state=42)

# %%
# Check the number of products in the English set

# products_eng.size

# %%
# Exctract the English sessions only (UK)

# sessions_eng = sessions[sessions['locale']=='UK']

# %%
# Check the number of sessions in the English set

# sessions_eng.size

# %% [markdown]
# We see that we have more items than distinct sessions

# %%
# continue data analysis ...

# %% [markdown]
# ### Clean

# %%
import re
import nltk

# %%
titles = np.array(products_eng['title'])
titles = " ".join(titles)

# %%
words = re.findall(r'\w+', titles)

# %%
word_counter = Counter(words)

# %%
word_frequencies = np.array(list(word_counter.values()))

# %%
word_quartiles = np.quantile(word_frequencies, [0,.45,0.5])
word_quartiles
# Out:
# array([1., 1., 2.])

# %%
len(word_frequencies)
# Out:
# 176991

# %%
word_freq_2_more = [k for k,v in word_counter.items() if float(v) >= 2]

# %%
len(word_freq_2_more)
# Out:
# 94355

# %%
big_count = 0

def clean(text, stem_words=True):
    
#     text = re.sub('(?<=[0-9])\,(?=[0-9])', "", text)
#     print(text)
#     text = re.sub('^(?!.[a-zA-Z])(?!.\d)[a-zA-Z0-9]+$', "", text)
    text = re.findall(r'\b(?:[a-zA-Z]+|\d+)\b', text)

    new_text = []
    for word in text:
        if word_counter[word] > 1:
            new_text.append(word)
    text = new_text

#     global big_count
#     big_count += 1
#     print(big_count)
    
    text = " ".join(text)
    
    return text

# %%
products_eng['title'] = products_eng['title'].apply(clean)

# %% [markdown]
# ### Model creation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# Problems:
# - items with no description
#
# Need to do:
# - normalize text (make undercase, no italic, no bold)

# %%
# Train a model that finds similar items based on the title of the items only
# https://www.datacamp.com/tutorial/recommender-systems-python

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

# #Replace NaN with an empty string
# products_eng['title'] = products_eng['title'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(products_eng['title'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (470148, 62117)

# %%
#Array mapping from feature integer indices to feature name

tfidf.get_feature_names_out()[-1000:]
# Out:
# array(['yinengd', 'yinfung', 'ying', 'yingbiao', 'yingcen', 'yingee',
#        'yingrace', 'yinke', 'yinlai', 'yinleader', 'yinler', 'yinsan',
#        'yintry', 'yinuo', 'yinuoday', 'yinuofa', 'yinva', 'yinyoo',
#        'yiouou', 'yipetor', 'yipinyin', 'yippee', 'yiran', 'yironkie',
#        'yirsur', 'yisan', 'yiseang', 'yishik', 'yisica', 'yisifeinuo',
#        'yisinuoo', 'yisitong', 'yisrlery', 'yissvic', 'yisuya',
#        'yitahome', 'yithao', 'yithinc', 'yitla', 'yitriden', 'yius',
#        'yiutera', 'yiviyar', 'yiweel', 'yiwentec', 'yiwer', 'yiwoo',
#        'yixia', 'yixisi', 'yiya', 'yiyoo', 'yiyuaniji', 'yizan',
#        'yizemay', 'yizerel', 'yizhet', 'yizish', 'yizyif', 'yjlx',
#        'yjwan', 'yjzq', 'yk', 'yking', 'ykk', 'ylab', 'ylang', 'ylc',
#        'yllee', 'ylong', 'ymccool', 'ymcrlux', 'ymdz', 'yme', 'ymenow',
#        'ymhpride', 'ymhxcy', 'ymina', 'yming', 'ymo', 'ymond', 'ymsz',
#        'ymwalk', 'ymx', 'ymyny', 'ynanimery', 'ynouu', 'ynr', 'ynwa',
#        'ynybusi', 'yo', 'yoart', 'yoassi', 'yobenki', 'yobola', 'yobon',
#        'yocada', 'yocowoco', 'yocuby', 'yoczox', 'yoda', 'yoden',
#        'yodoit', 'yodolla', 'yoelike', 'yofig', 'yofori', 'yoga',
#        'yogamatters', 'yogamedic', 'yogati', 'yoghurt', 'yoghurts',
#        'yoghurty', 'yogi', 'yogii', 'yogingo', 'yogo', 'yogurt', 'yohom',
#        'yohota', 'yohoz', 'yoillione', 'yoingo', 'yoisdtxc', 'yoiyee',
#        'yojock', 'yojogee', 'yojoloin', 'yoka', 'yoke', 'yokee',
#        'yokekon', 'yokilly', 'yoklili', 'yol', 'yolaist', 'yoleo',
#        'yoleostore', 'yolev', 'yolife', 'yolin', 'yolk', 'yolo',
#        'yolococa', 'yomaido', 'yomandamor', 'yomega', 'yomiko', 'yomshi',
#        'yondi', 'yonex', 'yongaijia', 'yongnkids', 'yongorhex', 'yonhee',
#        'yoni', 'yonii', 'yonisee', 'yontree', 'yonzone', 'yoocaa',
#        'yoodi', 'yoofan', 'yoofor', 'yoofoss', 'yoogeek', 'yoogeer',
#        'yoohoo', 'yookidoo', 'yooside', 'yootech', 'yoothbro', 'yoozoo',
#        'yop', 'yopih', 'yorbay', 'yordawn', 'yorgewd', 'yorha', 'yorja',
#        'york', 'yorkie', 'yorkies', 'yorking', 'yorkmills', 'yorkshire',
#        'yos', 'yosco', 'yosemite', 'yosemy', 'yosh', 'yoshi', 'yoshine',
#        'yosion', 'yosoan', 'yosou', 'yostar', 'yostyle', 'yosukata',
#        'yosun', 'yosuny', 'yotache', 'yotako', 'yotam', 'yotango',
#        'yotino', 'yotms', 'yoto', 'yotocversion', 'yoton', 'youcopia',
#        'youcute', 'youdenova', 'youdian', 'youerls', 'youga', 'yougarden',
#        'youghurt', 'youkoyi', 'youlehe', 'youlike', 'youmaker',
#        'youmaofa', 'youmen', 'youmi', 'youmile', 'young', 'youngbee',
#        'younger', 'youngest', 'youngever', 'youngine', 'youngly',
#        'youngman', 'youngrays', 'youngrich', 'youngs', 'youngsoul',
#        'younik', 'yourhealthstore', 'yourliteamz', 'yoursel',
#        'yourspares', 'yourzooki', 'yousafzai', 'yousave', 'youshah',
#        'youshares', 'youshiko', 'youtex', 'youth', 'youthful', 'youthink',
#        'youths', 'youtine', 'youtu', 'youtube', 'youtuber', 'youu',
#        'youview', 'youyijia', 'yowin', 'yoyi', 'yoyo', 'yoyofactory',
#        'yoyos', 'yozoti', 'yp', 'ypd', 'yplonon', 'ypselected', 'ypser',
#        'yqhbe', 'yqing', 'yql', 'yqxcc', 'yr', 'yrendenge', 'yrh',
#        'yrhealth', 'yrhome', 'yrong', 'yrprsodf', 'yrs', 'yru', 'yrym',
#        'ys', 'ysagi', 'ysamax', 'ysber', 'yseb', 'ysense', 'ysmjyh',
#        'yssmao', 'ysure', 'ysv', 'ytbubor', 'yteam', 'ytl', 'yu', 'yuai',
#        'yuan', 'yuaneang', 'yuanhot', 'yuanmiu', 'yuanqian', 'yuasa',
#        'yuauy', 'yubbaex', 'yubico', 'yubikey', 'yubx', 'yucalm',
#        'yucare', 'yucca', 'yuccer', 'yucky', 'yucoo', 'yudansi', 'yuderm',
#        'yudigest', 'yudote', 'yue', 'yuede', 'yuedge', 'yuefgoccy',
#        'yuejidz', 'yuekun', 'yues', 'yueser', 'yueshop', 'yuet',
#        'yugarlibi', 'yugi', 'yugioh', 'yuhengle', 'yuho', 'yuhtech',
#        'yuiip', 'yuki', 'yukihalu', 'yukiyi', 'yukool', 'yukung', 'yule',
#        'yuletide', 'yuloong', 'yulu', 'yuluki', 'yum', 'yumcarb',
#        'yumcute', 'yumega', 'yumi', 'yumkem', 'yummikeys',
#        'yumminecklace', 'yumms', 'yummy', 'yummyfood', 'yumore', 'yumove',
#        'yumsum', 'yumsur', 'yumzeco', 'yun', 'yunbaoit', 'yunbey',
#        'yunchi', 'yunchonguk', 'yungmax', 'yunju', 'yunjuer', 'yunlone',
#        'yunnasi', 'yunoun', 'yunstk', 'yunyoda', 'yuohee', 'yuoip',
#        'yupo', 'yuppie', 'yurayisen', 'yurdoca', 'yurnero', 'yurroad',
#        'yurt', 'yusaqmm', 'yusea', 'yushi', 'yushow', 'yuson', 'yusonic',
#        'yussi', 'yutaka', 'yutdeng', 'yuusei', 'yuv', 'yuwell', 'yuwldd',
#        'yuxiasan', 'yuyo', 'yuyu', 'yuzet', 'yuzhou', 'yuzu', 'yves',
#        'yvi', 'yvkvo', 'ywcking', 'ywineto', 'ywinler', 'ywlake',
#        'ywonoby', 'ywuly', 'yxhzvon', 'yxiaoo', 'yy', 'yyds', 'yydsxk',
#        'yyfitt', 'yyj', 'yyjop', 'yynn', 'yysg', 'yyshus', 'yyss',
#        'yzmewael', 'yznlife', 'yzp', 'yzpacc', 'yztex', 'yzyanzi',
#        'zaafaran', 'zabatoco', 'zabb', 'zabert', 'zaby', 'zac', 'zacal',
#        'zacapa', 'zacenyu', 'zachary', 'zack', 'zacro', 'zactly',
#        'zacuda', 'zada', 'zaexae', 'zafira', 'zag', 'zagg', 'zaggler',
#        'zahala', 'zahius', 'zahrvia', 'zaibier', 'zaione', 'zaiqun',
#        'zakazaka', 'zakira', 'zakvop', 'zalalas', 'zalando', 'zalava',
#        'zalgo', 'zalujmus', 'zam', 'zamaha', 'zamasha', 'zamerr',
#        'zamkol', 'zamo', 'zampa', 'zan', 'zane', 'zanesun', 'zange',
#        'zanimation', 'zanipro', 'zanlion', 'zanoty', 'zanussi',
#        'zanzibar', 'zaojup', 'zap', 'zapala', 'zapf', 'zapig', 'zapper',
#        'zappers', 'zappi', 'zapping', 'zaqi', 'zara', 'zaradna',
#        'zarahill', 'zarb', 'zarela', 'zarpma', 'zarsyn', 'zashmart',
#        'zasunky', 'zatech', 'zatruize', 'zatyorg', 'zawadi', 'zawtr',
#        'zaxideel', 'zaxop', 'zayin', 'zayvor', 'zazu', 'zbbridge', 'zbed',
#        'zbmini', 'zbrands', 'zbtop', 'zbw', 'zbzyxa', 'zccz', 'zcda',
#        'zcdaye', 'zcgel', 'zcoins', 'zcooooool', 'zczn', 'zczuox',
#        'zdada', 'zdkger', 'zdycgtime', 'zdzblx', 'ze', 'zeacct', 'zeadio',
#        'zeal', 'zealand', 'zealife', 'zealsound', 'zeato', 'zeaxanthin',
#        'zeayebsr', 'zeberine', 'zebra', 'zebras', 'zebre', 'zechstein',
#        'zed', 'zedyoe', 'zee', 'zeefo', 'zeerkeer', 'zeester', 'zeetaq',
#        'zeex', 'zeexipdr', 'zeeyrak', 'zeeyuan', 'zefal', 'zefan',
#        'zefffka', 'zegna', 'zeina', 'zeiss', 'zejia', 'zek', 'zelaxy',
#        'zelda', 'zellar', 'zellux', 'zelos', 'zeltauto', 'zemiu',
#        'zemolo', 'zemty', 'zen', 'zenacolor', 'zenart', 'zenb', 'zenbook',
#        'zendium', 'zendure', 'zenga', 'zengaoou', 'zenghh', 'zenhof',
#        'zenida', 'zenith', 'zenitsu', 'zenker', 'zennox', 'zeno',
#        'zenoplige', 'zenottic', 'zenpad', 'zenpur', 'zenqa', 'zens',
#        'zenscreen', 'zentai', 'zentesi', 'zenvaly', 'zenwifi', 'zeo',
#        'zeoderm', 'zeonhei', 'zep', 'zeppoli', 'zepra', 'zeqeey', 'zer',
#        'zeraora', 'zerhok', 'zero', 'zerobase', 'zerodeco', 'zerodeko',
#        'zeroderma', 'zerodis', 'zerostick', 'zerotop', 'zeroveen',
#        'zerowater', 'zes', 'zesc', 'zesen', 'zeskit', 'zeskris',
#        'zesnice', 'zest', 'zester', 'zesting', 'zesty', 'zetong',
#        'zetuvit', 'zeus', 'zevnico', 'zexrow', 'zeyar', 'zeydan',
#        'zezirdas', 'zf', 'zfyq', 'zgmj', 'zgoec', 'zgts', 'zha',
#        'zhailyn', 'zhanmai', 'zhaoco', 'zhddm', 'zhege', 'zhengyue',
#        'zhenle', 'zhezhe', 'zhichengbosi', 'zhiheng', 'zhihui', 'zhio',
#        'zhiqiang', 'zhiqin', 'zhiqiyi', 'zhirceke', 'zhitong', 'zhiye',
#        'zhjuju', 'zhma', 'zhonggemei', 'zhongren', 'zhongtou', 'zhoorqi',
#        'zhou', 'zhouduidui', 'zhoustou', 'zhu', 'zhujiehigh', 'zhulia',
#        'zhuofan', 'zhurson', 'zhuyun', 'zhziro', 'zi', 'zibly', 'zicosy',
#        'zidane', 'zidina', 'zidior', 'zieler', 'ziffs', 'zig', 'zigbee',
#        'ziggle', 'ziggy', 'zigjoy', 'zigmoon', 'zigtiger', 'zigzag',
#        'zigzagger', 'zihnic', 'zihua', 'zijiu', 'ziko', 'zikrange',
#        'zilead', 'zillerate', 'zimaoshan', 'zimasilk', 'zimel', 'zimmer',
#        'zimoon', 'zimpli', 'zinc', 'zindoo', 'zinel', 'zinfandel', 'zing',
#        'zingso', 'zingy', 'zingyzoo', 'zinibri', 'zink', 'zinsser',
#        'zinus', 'zinuu', 'zinz', 'ziocom', 'zioxx', 'zip', 'zipbin',
#        'zipit', 'zipline', 'ziploc', 'ziplock', 'zipom', 'zipp', 'zippa',
#        'zipped', 'zipper', 'zippered', 'zippers', 'zippi', 'zippo',
#        'zippy', 'zips', 'ziptie', 'zipties', 'zircon', 'zircondia',
#        'zirconia', 'zircons', 'zirtek', 'zisma', 'zissou', 'zit', 'zita',
#        'zitfri', 'zits', 'zitsticka', 'ziuheoa', 'ziukenr', 'zivisk',
#        'zivsivc', 'ziwodiv', 'zixxone', 'ziyituod', 'ziyiui', 'ziyou',
#        'zizi', 'zizor', 'zj', 'zjfksdyx', 'zjoey', 'zjstyle', 'zkapor',
#        'zksm', 'zksmnb', 'zktsry', 'zl', 'zlide', 'zlyc', 'zm', 'zma',
#        'zmark', 'zmcyn', 'zmile', 'zmkar', 'zmlm', 'zmodo', 'zms',
#        'zmtech', 'zndftw', 'zngou', 'znm', 'znoka', 'znr', 'znwindsor',
#        'znycye', 'znz', 'zober', 'zoccee', 'zocipro', 'zocone', 'zocoyuu',
#        'zodiac', 'zodight', 'zoe', 'zoemini', 'zoenhou', 'zoeon',
#        'zoeson', 'zoestar', 'zoetec', 'zoey', 'zoff', 'zoflora', 'zofore',
#        'zog', 'zoggs', 'zoggy', 'zogoflex', 'zogplg', 'zogs', 'zohan',
#        'zois', 'zolische', 'zoll', 'zollen', 'zollipops', 'zolt',
#        'zolure', 'zomake', 'zombaflo', 'zombie', 'zombies', 'zomiboo',
#        'zon', 'zona', 'zone', 'zoned', 'zonefoker', 'zones', 'zoneyan',
#        'zonfer', 'zonon', 'zonpor', 'zonsen', 'zonster', 'zonstore',
#        'zonsuse', 'zonzhi', 'zoo', 'zooaoxo', 'zooaux', 'zooawa',
#        'zoobles', 'zoodle', 'zooi', 'zookao', 'zookeeper', 'zookey',
#        'zooki', 'zoolander', 'zoom', 'zooma', 'zoomable', 'zoomgroom',
#        'zoomy', 'zoonnis', 'zoonpark', 'zoopla', 'zootop', 'zootzi',
#        'zoowing', 'zopaly', 'zorax', 'zorela', 'zorgo', 'zorra', 'zorro',
#        'zorssar', 'zosen', 'zosi', 'zotin', 'zotoyi', 'zotti', 'zou',
#        'zouiqss', 'zouk', 'zounich', 'zouyue', 'zovira', 'zovirax',
#        'zowie', 'zoyii', 'zoylink', 'zoyu', 'zp', 'zpicjng', 'zpose',
#        'zpx', 'zqo', 'zr', 'zrsdixki', 'zs', 'zsb', 'zsirue', 'zsn',
#        'zsta', 'zte', 'ztmy', 'ztofera', 'ztoone', 'ztotop', 'ztotopcase',
#        'ztotopcases', 'ztsy', 'ztt', 'ztuok', 'ztxpro', 'zu', 'zubita',
#        'zubufitd', 'zubyshax', 'zucchini', 'zucng', 'zues', 'zueyen',
#        'zugati', 'zugspitze', 'zugu', 'zuhause', 'zuikaku', 'zujo',
#        'zukkashan', 'zulay', 'zulfaye', 'zulu', 'zum', 'zuma', 'zumba',
#        'zunea', 'zunseat', 'zunto', 'zuolan', 'zuoox', 'zupora', 'zurg',
#        'zurich', 'zuru', 'zurzache', 'zuvo', 'zuyoki', 'zv', 'zvoansem',
#        'zvonema', 'zvzm', 'zwanzer', 'zwcegnd', 'zweigart', 'zwiesel',
#        'zwift', 'zwilling', 'zwini', 'zwmbyn', 'zwmy', 'zwoos', 'zwr',
#        'zwznbl', 'zxcp', 'zxfd', 'zxk', 'zxrsjbl', 'zy', 'zybux',
#        'zyclops', 'zyfc', 'zygmir', 'zygomatic', 'zyhltd', 'zyklop',
#        'zyliss', 'zylkene', 'zymurgorium', 'zynery', 'zyooo', 'zysy',
#        'zyuton', 'zyxel', 'zyyxb', 'zz', 'zzafdz', 'zzewintraveler',
#        'zzlbuf', 'zzlife', 'zzlove', 'zzlovecoffin', 'zzzmoon', '𝟐𝟎𝟐𝟐',
#        '𝟮𝟬𝟮𝟮', '𝟯𝟔𝟎'], dtype=object)

# %%
# Import linear_kernel

from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity

# %%
# # https://github.com/AlexanderNixon/Machine-learning-reads/blob/master/Movie-content-based-recommender-using-tf-idf.ipynb

# cosine_sim = cosine_similarity(tfidf_matrix)

# %%
# tfidf_matrix = tfidf_matrix.astype('float32')

# %%
def get_closest_item(item_id):
    return None

# %%
tfidf_matrix[0]
# Out:
# <1x148193 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>

# %%
# Compute the cosine similarity matrix

cosine_sim = linear_kernel(tfidf_matrix[0], tfidf_matrix)

# %%
cosine_sim.shape
# Out:
# (14692, 14692)

# %%
#Construct a reverse map of indices and item titles

indices = pd.Series(products_eng.index, index=products_eng['title']).drop_duplicates()

# %%
indices
# Out:
# title
# Canny Collar No Pull Dog Head Collar Lead Training Head Harness Dog Collar that stops pulling Easy to fit simple to use kind safe comfortable                                      947223
# Make It Real DIY Plush Toys Pom Pom Characters Making Kit Arts and Crafts for Kids Gifts for Girls                                                                                1286748
# Hanger 32 Pegs Flexible Underwear Socks Hanging Rack Folding Multifunctional In outdoor Washing Laundry Dryer Grey                                                                1206734
# WOWLED 10 X Dimmable LED Capsule Light Bulbs Equivalent Cool White for Chandelier Home Lighting 360 Beam Angle                                                                    1223035
# Curly Human Hair Wig Short Bob Brazilian Wigs for Black Women Middle Part Afro Curly Wig 150 Density Real Hair Wigs for Women Natural black                                       1268552
#                                                                                                                                                                                    ...
# Small Victorian square plastic sweet jars Pack of 6 by Britten James These small jars look great filled with sweets on a wedding table or party display or as individual gifts    1290401
# Bomb Cosmetics Christmas Carol Handmade Wrapped Bath and Body Gift Pack Contains 5 Pieces 480 g                                                                                   1239793
# HEAVY DUTY LARGE PICTURE MIRROR HANGING KIT UP TO                                                                                                                                 1337922
# 2 Leg Trouser Suit Dog Raincoat with high Waterproof for Dogs Reflective Four Leg rain Gear Jumpsuit for Puppies Small Medium pet Navy XL                                         1338481
# SOLUSTRE Flower Hairpin Rose Hair Clip Elegant Flower Bobby Pin Women Rose Flower Hair Accessories for Ladies Girls Valentines Day Decoration Red                                 1008869
# Length: 14692, dtype: int64

# %% [markdown]
# For report:
#
# - more than half of words used only once
# - a lot of products which are not rented
